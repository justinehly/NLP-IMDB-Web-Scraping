# %% [markdown]
# ### Justin Ehly
# #### HW5 - NLP
# #### Answer explanations and discussion are after the code for each section.
#
#
# ---
# ##### Exercise
# 1.	Compile a list of static links (permalinks) to individual user movie reviews from one particular website. This will be your working dataset for this assignment, as well as for assignments 7 and 8.
# - a.	It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links. Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
# - b.	Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
# - c.	Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
# - d.	Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.

# %%
import numpy as np
import requests
import re
import nltk
from bs4 import BeautifulSoup

# %%
class scraper():
    '''
        Build web scraper to gather the top 50 comedies from imdb.com
        - gather the titles and individual comedy movie page urls
        - gather the main talent in each movie, mainly director(s) and main star(s)
        - gather the permalinks to <user selected> user comments from each movie's page
        - remove movies that don't have any comments
    '''
    
    def __init__(self, reviews):

        # set imdb header
        self.imdb_header = 'https://www.imdb.com'
        
        # set imdb reviews footer
        self.review_footer = 'reviews?ref_=tt_urv'        
        
        # number of movie reviews per movie
        self.movie_reviews = reviews
    

    # get a list of the 50 comedies listed on the top comedies page on imdb along with the link to each movie's individual page    
    def get_comedies(self):
        # download 50 comedy movie titles and links from imdb
        URL = 'https://www.imdb.com/search/title/?genres=comedy&explore=title_type,genres&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=3396781f-d87f-4fac-8694-c56ce6f490fe&pf_rd_r=E9DKJDX8CMCD24P485G8&pf_rd_s=center-1&pf_rd_t=15051&pf_rd_i=genre&ref_=ft_gnr_pr1_i_1'
        response = requests.get(URL)
        soup = BeautifulSoup(response.text, 'lxml')

        # grab page contents with movie links and titles
        movies = soup.select('h3.lister-item-header')    

        # get links to each movie page
        movie_links = [link.attrs.get('href') for link in soup.select('h3.lister-item-header a')]
        movie_links = [self.imdb_header + link for link in movie_links]
        movie_links = [link + self.review_footer for link in movie_links]
        self.movie_links = movie_links
        
        # extrap the titles/ actors
        comedy_titles = []
        for idx, movie in enumerate(movies):
            ms = movie.get_text()
            mov = (' '.join(ms.split()).replace('.',''))
            mov = mov.split(' (')[0]
            mov = mov[len(str(idx))+1:]
            comedy_titles.append(mov)
        self.comedy_titles = comedy_titles
        
        # get the main directors and actors
        talent = soup.findAll('p', {'class':''})
        all_talent = []
        for t in talent:  # return a chunk of html with director and stars with titles, needs to be cleaned up
            ms = t.text      # just grab the text from the html
            names = ' '.join(ms.split()).replace('.','')    # extrap the names and titles
            if str.find(names,'|'):         # split up the list by titles ('Director(s)', 'Star(s)')
                names = names.split('|')
            talent = []
            for n in names:
                talent.append(n.split(': ')[1])   # drop the title from each list

            talent = [t.split(', ') for t in talent]
            talent = [item for sublist in talent for item in sublist]

            #clean up spaces at the beginning or end in case they escaped
            talent = [i[1:] if i[0] == ' ' else i[:-1] if i[-1]== ' ' else i for i in talent]
            all_talent.append(talent)
        
        all_talent = [n for m in all_talent for n in m]  # unpack the list of names
        all_talent = set(all_talent) # remove duplicates!
        
        self.talent_names = all_talent
        
        

    # grab the permalinks from each comedy's move page on imdb    
    def get_permalinks(self):
        self.get_comedies()
        movie_links = self.movie_links
        permalinks = []
        for link in movie_links:
            response = requests.get(link)
            soup = BeautifulSoup(response.text, 'lxml')
            plinks = [self.imdb_header + link.attrs.get('href') for link in soup.select('div.actions.text-muted a') if link.attrs.get('href')[1:7] == 'review']
            plinks = plinks[ 0 : self.movie_reviews ]
            permalinks.append(plinks)
        
        
        self.permalinks = permalinks
        
        self.clean_up()
        
        return self

    # remove the movies with less than 5 reviews
    def clean_up(self):
        for x,i in enumerate(self.permalinks):
            if len(i) < 5:
                self.permalinks.pop(x)
                self.comedy_titles.pop(x)
                self.movie_links.pop(x)
        return self
    
       
# pass how many reviews per movie
imdb = scraper(5).get_permalinks()

# %%
count_permalinks = len([item for sublist in imdb.permalinks for item in sublist])
print(f'There are {count_permalinks} permalinks for {len(imdb.comedy_titles)} comedies with a total of {len(imdb.talent_names)} unqiue directors and actors from the imdb website')
# Out:
# There are 245 permalinks for 49 comedies with a total of 213 unqiue directors and actors from the imdb website

# %% [markdown]
# Comments: End #1
#
# ---
# Exercise #2: Extract noun phrase (NP) chunks from your reviews using the following procedure:
# - a.	In Python, use BeautifulSoup to grab the main review text from each link.
# - b.	Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.
# - c.	You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.

# %%
# Use Beautiful Soup to extract the reviews from each review page within imbd.
links = imdb.permalinks[0]

class movie_reviews():
    def __init__(self, permalinks_list):
        self.permalinks_list = permalinks_list
        
    # cycle through all movies and return a list of lists of movie reviews for each movie
    def get_movie_reviews(self):
        reviews = []
        for single_movie_permalinks in self.permalinks_list:
            single_comedy_reviews = self.movie_review_page_cycling(single_movie_permalinks)
            reviews.append(single_comedy_reviews)
        
        self.reviews = reviews
        return self

    # cycle through each movie's pages of reviews
    def movie_review_page_cycling(self, links):
        reviews = []
        for link in links:
            review = self.get_review(link)
            reviews.append(review)
        
        return reviews

    # get single review
    def get_review(self, link):
        response = requests.get(link)
        soup = BeautifulSoup(response.text, 'lxml')
         
        review =  soup.find('div', {'class':'text show-more__control'}).text
        return review


#reviews = movie_review_page_cycling(links)
#print(f'Reviews for {imdb.comedy_titles[0]}')
#for review in reviews:
#    print(f'{review}\n')

# only pass the first 100 permalinks from the first 20 comedies
reviews = movie_reviews(imdb.permalinks[:20]).get_movie_reviews()

# %%
# unpack the movie reviews into a list of 100 reviews!
movie_reviews = [item for sublist in reviews.reviews for item in sublist]
len(movie_reviews)
# Out:
# 100

# %%
movie_reviews[0]
# Out:
# "From the world of dc comics, john cena is chris smith, self proclaimed peacemaker. He's strong enough to bail from the hospital, so he's back on the job. This opens with a quick summary of what came before. His mission, his jail sentence. And of course, the chip in his head that they can pop if he doesn't obey. So much cussing. And the violence. Not for the kiddies. When a one night stand goes very wrong, he realizes he's already caught up in a new mission. With harcourt and the crew to back him up, he's off to fight the butterflies. Lots of silly banter. Showing on hbomax. Good stuff! A new team member too. Written (and some episodes directed) by james gunn. Also did a whole lot of guardians of the galaxy."

# %% [markdown]
# ---
#
# - b.	Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.

# %%
# preprocess each review by tokenize each sentence, then each word, then POS tage each word
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk import pos_tag

class prepare():
    def __init__(self):
        self = self       
        
    def tokenized_single_review(self, review):
        sentences = nltk.sent_tokenize(review)
        sentences = [nltk.word_tokenize(sent) for sent in sentences]
        sentences = [nltk.pos_tag(sent) for sent in sentences]
        return sentences

    def token_reviews(self, reviews):
        tokenized_reviews = [self.tokenized_single_review(review) for review in reviews]
        return tokenized_reviews
        
prep = prepare()
tok_reviews = prep.token_reviews(movie_reviews)

# %%
tok_reviews[0][0]
# Out:
# [('From', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('of', 'IN'),
#  ('dc', 'NN'),
#  ('comics', 'NNS'),
#  (',', ','),
#  ('john', 'NN'),
#  ('cena', 'NN'),
#  ('is', 'VBZ'),
#  ('chris', 'JJ'),
#  ('smith', 'NN'),
#  (',', ','),
#  ('self', 'NN'),
#  ('proclaimed', 'VBD'),
#  ('peacemaker', 'NN'),
#  ('.', '.')]

# %%
# let's see how many of each pos we have
from collections import Counter

       
s = unpacked_pos_words = [pos for sent in [sent for review in tok_reviews for sent in review] for pos in sent]
print(Counter([tag for word, tag in s]))
# Out:
# Counter({'NN': 3700, 'DT': 2735, 'IN': 2665, 'NNP': 2003, 'JJ': 1934, 'RB': 1531, 'PRP': 1352, 'VBZ': 1293, ',': 1237, '.': 1186, 'CC': 1027, 'NNS': 1015, 'VB': 781, 'VBP': 573, 'TO': 550, 'VBD': 532, 'VBG': 508, 'VBN': 471, 'PRP$': 326, 'CD': 261, 'MD': 250, '(': 183, ')': 182, ':': 175, 'POS': 151, 'WP': 147, 'WRB': 139, 'WDT': 133, 'RP': 129, "''": 98, '``': 92, 'JJR': 78, 'JJS': 71, 'EX': 64, 'RBR': 39, 'PDT': 25, 'RBS': 19, 'NNPS': 14, 'UH': 11, 'FW': 8, '$': 4, 'WP$': 3, '#': 1})

# %%
print(set([x for i,x in s if x not in ['#', '$', "''", '(', ')', ',', '.', ':','``']]))
# Out:
# {'WDT', 'JJ', 'NNP', 'UH', 'NNPS', 'PDT', 'NNS', 'TO', 'CC', 'VBN', 'VB', 'RBR', 'POS', 'FW', 'VBD', 'RB', 'VBG', 'PRP', 'NN', 'VBP', 'CD', 'JJS', 'DT', 'WP', 'WRB', 'JJR', 'MD', 'RBS', 'WP$', 'IN', 'PRP$', 'RP', 'VBZ', 'EX'}

# %%
from nltk.chunk.regexp import RegexpParser


def chunk_my_reviews(reviews):
    #grammar = """
    #    NP: {<DT>?<JJ>?<NN.*>}
    #    ADJP: {<JJ>}
    #    ADVB: {<RB.*>}
    #    PP: {<IN>}
    #    VP: {<MD>?<VB.*>+}
    #   """
    grammar = """
        NP: {<DT>?<JJ>?<NN.*>}
    """
    
    chunker = RegexpParser(grammar, loop=1)
    chunked_reviews = [[chunker.parse(sentence) for sentence in review] for review in tok_reviews]
    return chunked_reviews

chunked_reviews = chunk_my_reviews(tok_reviews)
 
# example of the first sentence of the first review

chunked_reviews[0]    
# what we see here is that the chunker is picking up on the proper nouns, but misclassifying.
# Out:
# [Tree('S', [('From', 'IN'), Tree('NP', [('the', 'DT'), ('world', 'NN')]), ('of', 'IN'), Tree('NP', [('dc', 'NN')]), Tree('NP', [('comics', 'NNS')]), (',', ','), Tree('NP', [('john', 'NN')]), Tree('NP', [('cena', 'NN')]), ('is', 'VBZ'), Tree('NP', [('chris', 'JJ'), ('smith', 'NN')]), (',', ','), Tree('NP', [('self', 'NN')]), ('proclaimed', 'VBD'), Tree('NP', [('peacemaker', 'NN')]), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('strong', 'JJ'), ('enough', 'RB'), ('to', 'TO'), ('bail', 'VB'), ('from', 'IN'), Tree('NP', [('the', 'DT'), ('hospital', 'NN')]), (',', ','), ('so', 'IN'), ('he', 'PRP'), ("'s", 'VBZ'), ('back', 'RB'), ('on', 'IN'), Tree('NP', [('the', 'DT'), ('job', 'NN')]), ('.', '.')]),
#  Tree('S', [('This', 'DT'), ('opens', 'VBZ'), ('with', 'IN'), Tree('NP', [('a', 'DT'), ('quick', 'JJ'), ('summary', 'NN')]), ('of', 'IN'), ('what', 'WP'), ('came', 'VBD'), ('before', 'RB'), ('.', '.')]),
#  Tree('S', [('His', 'PRP$'), Tree('NP', [('mission', 'NN')]), (',', ','), ('his', 'PRP$'), Tree('NP', [('jail', 'NN')]), Tree('NP', [('sentence', 'NN')]), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('of', 'IN'), Tree('NP', [('course', 'NN')]), (',', ','), Tree('NP', [('the', 'DT'), ('chip', 'NN')]), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('head', 'NN')]), ('that', 'IN'), ('they', 'PRP'), ('can', 'MD'), ('pop', 'VB'), ('if', 'IN'), ('he', 'PRP'), ('does', 'VBZ'), ("n't", 'RB'), ('obey', 'VB'), ('.', '.')]),
#  Tree('S', [('So', 'RB'), Tree('NP', [('much', 'JJ'), ('cussing', 'NN')]), ('.', '.')]),
#  Tree('S', [('And', 'CC'), Tree('NP', [('the', 'DT'), ('violence', 'NN')]), ('.', '.')]),
#  Tree('S', [('Not', 'RB'), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('kiddies', 'NNS')]), ('.', '.')]),
#  Tree('S', [('When', 'WRB'), ('a', 'DT'), ('one', 'CD'), Tree('NP', [('night', 'NN')]), Tree('NP', [('stand', 'NN')]), ('goes', 'VBZ'), ('very', 'RB'), ('wrong', 'JJ'), (',', ','), ('he', 'PRP'), ('realizes', 'VBZ'), ('he', 'PRP'), ("'s", 'VBZ'), ('already', 'RB'), ('caught', 'VBN'), ('up', 'RP'), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('new', 'JJ'), ('mission', 'NN')]), ('.', '.')]),
#  Tree('S', [('With', 'IN'), Tree('NP', [('harcourt', 'NN')]), ('and', 'CC'), Tree('NP', [('the', 'DT'), ('crew', 'NN')]), ('to', 'TO'), ('back', 'VB'), ('him', 'PRP'), ('up', 'RP'), (',', ','), ('he', 'PRP'), ("'s", 'VBZ'), ('off', 'IN'), ('to', 'TO'), ('fight', 'VB'), Tree('NP', [('the', 'DT'), ('butterflies', 'NNS')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('Lots', 'NNS')]), ('of', 'IN'), Tree('NP', [('silly', 'JJ'), ('banter', 'NN')]), ('.', '.')]),
#  Tree('S', [('Showing', 'VBG'), ('on', 'IN'), Tree('NP', [('hbomax', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('NP', [('Good', 'JJ'), ('stuff', 'NN')]), ('!', '.')]),
#  Tree('S', [Tree('NP', [('A', 'DT'), ('new', 'JJ'), ('team', 'NN')]), Tree('NP', [('member', 'NN')]), ('too', 'RB'), ('.', '.')]),
#  Tree('S', [Tree('NP', [('Written', 'NNP')]), ('(', '('), ('and', 'CC'), Tree('NP', [('some', 'DT'), ('episodes', 'NNS')]), ('directed', 'VBN'), (')', ')'), ('by', 'IN'), Tree('NP', [('james', 'NNS')]), Tree('NP', [('gunn', 'NNS')]), ('.', '.')]),
#  Tree('S', [('Also', 'RB'), ('did', 'VBD'), Tree('NP', [('a', 'DT'), ('whole', 'NN')]), Tree('NP', [('lot', 'NN')]), ('of', 'IN'), Tree('NP', [('guardians', 'NNS')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('galaxy', 'NN')]), ('.', '.')])]

# %% [markdown]
# - c.	You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.

# %%
# now we need to scrape the actor names from the movie pages (but we have those links!) - this was actually added to the Scrape class as talent_names and a set was used to remove any duplicates from the extraction process.
tal = [name for name in imdb.talent_names]        

# separate the fnames, mnames, lnames, etc
tal = [name.split(' ') for name in tal]
# break apart the name lists and remove duplicates
tal = list(set([name for fullname in tal for name in fullname]))
tal.sort()
#tal

# %%
# set up the talent names with tags
tnames = [nltk.word_tokenize(name) for name in tal]
tnames = [nltk.pos_tag(name) for name in tnames]

# %%
count_tal_tags = [pos for tag in tnames for pos in tag]
Counter([tag for name, tag in count_tal_tags])
# Out:
# Counter({'NN': 264,
#          'NNP': 95,
#          'FW': 2,
#          'NNS': 21,
#          'VB': 4,
#          'VBG': 1,
#          'JJ': 9,
#          'VBN': 2,
#          'RB': 1,
#          'IN': 1,
#          'MD': 1})

# %%
# after much trail and error ( 3 days of work) and a lot of deleted code, I cannot figure out how to manually update the pos tagging for rechunkinig.

# %% [markdown]
# ---
#
# 3.	Output all the chunks in a single list for each review, and submit that output for this assignment. Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews, how many you collected, and by what means).
# <br>
#
# #### Summary
#
# ##### IMDB Site Scrubbing
# I started the homework assignment using Beautiful Soup to scrape the list of the top 50 comedies from imdb.com that included the  comedy title, link to the movie’s page, main talent in the movie (Directors and Actors) and permalinks to each individual review. Since the scope of this project was limited to 100 reviews, I only used the first 5 reviews of the top 20 movies and ensured there were at least 5 reviews for each movie. This was done using a combination of list comprehensions within functions within a class object.
#
# ##### NP-chunk
# In this section I used the permalinks to grab the individual reviews for each of the top 20 movies (that had at least 5 reviews, note of the 50, only 1 comey did not have 5 reviews and that is because it has not been released it and stars Sandra Bullock).
#
# I then used the NLTK sent_tokenizer, word_tokenizer and pos_tag functions to breakdown each movie review using a combination of list comprehensions within functions within a class. I then inspected the first sentence of the first review our of curiosity.
#
# Next I checked to see if there were any missing chunks by using the Counter from the collections package to count how many of each POS existed in my corpus…to my surprise, there were 182 with a very strange label, that on further inspection returned a null list so it might’ve been some blank space lurking.
#
# Next I just chunked for Noun Phrase chunks using the RegexpParser and a manual grammar setting of NP: {<DT>?<JJ>?<NN.*>}
#
# ##### Wrap it up
# After about 3 days of trial and error, well just error, I could not figure out how to add anything to the lexicon nor manually update the talent name POS tags in order to re-chunk. But I did ensure that all the names I scraped from the IMDB website were represented in the POS tags; although, only 95 were correctly tagged as NNP, so there is a chance that quite a bit of information was lost in this process.
# <br> Below is the output of how the pos_tag thought they should be represented:
# <br> 'NN': 264,
# <br> 'NNP': 95,
# <br> 'FW': 2,
# <br> 'NNS': 21,
# <br> 'VB': 4,
# <br> 'VBG': 1,
# <br> 'JJ': 9,
# <br> 'VBN': 2,
# <br> 'RB': 1,
# <br> 'IN': 1,
# <br> 'MD': 1})

# %%
m = 0
for i,chunk in enumerate(chunked_reviews):
    if i in [0,5,10,15,20]:
        print(f'{imdb.comedy_titles[m]} Movie Reviews Chunked:')
        m += 1
    print(f'{chunk}\n')
# Out:
# Peacemaker Movie Reviews Chunked:
# [Tree('S', [('From', 'IN'), Tree('NP', [('the', 'DT'), ('world', 'NN')]), ('of', 'IN'), Tree('NP', [('dc', 'NN')]), Tree('NP', [('comics', 'NNS')]), (',', ','), Tree('NP', [('john', 'NN')]), Tree('NP', [('cena', 'NN')]), ('is', 'VBZ'), Tree('NP', [('chris', 'JJ'), ('smith', 'NN')]), (',', ','), Tree('NP', [('self', 'NN')]), ('proclaimed', 'VBD'), Tree('NP', [('peacemaker', 'NN')]), ('.', '.')]), Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('strong', 'JJ'), ('enough', 'RB'), ('to', 'TO'), ('bail', 'VB'), ('from', 'IN'), Tree('NP', [('the', 'DT'), ('hospital', 'NN')]), (',', ','), ('so', 'IN'), ('he', 'PRP'), ("'s", 'VBZ'), ('back', 'RB'), ('on', 'IN'), Tree('NP', [('the', 'DT'), ('job', 'NN')]), ('.', '.')]), Tree('S', [('This', 'DT'), ('opens', 'VBZ'), ('with', 'IN'), Tree('NP', [('a', 'DT'), ('quick', 'JJ'), ('summary', 'NN')]), ('of', 'IN'), ('what', 'WP'), ('came', 'VBD'), ('before', 'RB'), ('.', '.')]), Tree('S', [('His', 'PRP$'), Tree('NP', [('mission', 'NN')]), (',', ','), ('his', 'PRP$'), Tree('NP', [('jail', 'NN')]), Tree('NP', [('sentence', 'NN')]), ('.', '.')]), Tree('S', [('And', 'CC'), ('of', 'IN'), Tree('NP', [('course', 'NN')]), (',', ','), Tree('NP', [('the', 'DT'), ('chip', 'NN')]), ('in', 'IN'), ('his', 'PRP$'), Tree('NP', [('head', 'NN')]), ('that', 'IN'), ('they', 'PRP'), ('can', 'MD'), ('pop', 'VB'), ('if', 'IN'), ('he', 'PRP'), ('does', 'VBZ'), ("n't", 'RB'), ('obey', 'VB'), ('.', '.')]), Tree('S', [('So', 'RB'), Tree('NP', [('much', 'JJ'), ('cussing', 'NN')]), ('.', '.')]), Tree('S', [('And', 'CC'), Tree('NP', [('the', 'DT'), ('violence', 'NN')]), ('.', '.')]), Tree('S', [('Not', 'RB'), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('kiddies', 'NNS')]), ('.', '.')]), Tree('S', [('When', 'WRB'), ('a', 'DT'), ('one', 'CD'), Tree('NP', [('night', 'NN')]), Tree('NP', [('stand', 'NN')]), ('goes', 'VBZ'), ('very', 'RB'), ('wrong', 'JJ'), (',', ','), ('he', 'PRP'), ('realizes', 'VBZ'), ('he', 'PRP'), ("'s", 'VBZ'), ('already', 'RB'), ('caught', 'VBN'), ('up', 'RP'), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('new', 'JJ'), ('mission', 'NN')]), ('.', '.')]), Tree('S', [('With', 'IN'), Tree('NP', [('harcourt', 'NN')]), ('and', 'CC'), Tree('NP', [('the', 'DT'), ('crew', 'NN')]), ('to', 'TO'), ('back', 'VB'), ('him', 'PRP'), ('up', 'RP'), (',', ','), ('he', 'PRP'), ("'s", 'VBZ'), ('off', 'IN'), ('to', 'TO'), ('fight', 'VB'), Tree('NP', [('the', 'DT'), ('butterflies', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('Lots', 'NNS')]), ('of', 'IN'), Tree('NP', [('silly', 'JJ'), ('banter', 'NN')]), ('.', '.')]), Tree('S', [('Showing', 'VBG'), ('on', 'IN'), Tree('NP', [('hbomax', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Good', 'JJ'), ('stuff', 'NN')]), ('!', '.')]), Tree('S', [Tree('NP', [('A', 'DT'), ('new', 'JJ'), ('team', 'NN')]), Tree('NP', [('member', 'NN')]), ('too', 'RB'), ('.', '.')]), Tree('S', [Tree('NP', [('Written', 'NNP')]), ('(', '('), ('and', 'CC'), Tree('NP', [('some', 'DT'), ('episodes', 'NNS')]), ('directed', 'VBN'), (')', ')'), ('by', 'IN'), Tree('NP', [('james', 'NNS')]), Tree('NP', [('gunn', 'NNS')]), ('.', '.')]), Tree('S', [('Also', 'RB'), ('did', 'VBD'), Tree('NP', [('a', 'DT'), ('whole', 'NN')]), Tree('NP', [('lot', 'NN')]), ('of', 'IN'), Tree('NP', [('guardians', 'NNS')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('galaxy', 'NN')]), ('.', '.')])]
#
# [Tree('S', [('My', 'PRP$'), Tree('NP', [('favorite', 'JJ'), ('character', 'NN')]), ('in', 'IN'), ('``', '``'), Tree('NP', [('The', 'DT'), ('Suicide', 'NNP')]), Tree('NP', [('Squad', 'NNP')]), ("''", "''"), ('was', 'VBD'), ('``', '``'), Tree('NP', [('Peacemaker', 'NNP')]), ("''", "''"), (',', ','), ('but', 'CC'), ('when', 'WRB'), ('I', 'PRP'), ('heard', 'VBD'), ('that', 'IN'), Tree('NP', [('the', 'DT'), ('Series', 'NNP')]), ('was', 'VBD'), ('going', 'VBG'), ('to', 'TO'), ('be', 'VB'), ('made', 'VBN'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('very', 'RB'), ('enthusiastic', 'JJ'), (',', ','), ('but', 'CC'), ('I', 'PRP'), ('watched', 'VBD'), ('it', 'PRP'), ('anyway', 'RB'), ('and', 'CC'), ('said', 'VBD'), ('``', '``'), Tree('NP', [('wow', 'NN')]), ("''", "''"), ('.', '.')]), Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('4', 'CD'), Tree('NP', [('times', 'NNS')]), ('better', 'JJR'), Tree('NP', [('series', 'NN')]), ('than', 'IN'), ('I', 'PRP'), ('expected', 'VBD'), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('acting', 'NN')]), ('was', 'VBD'), ('perfect', 'JJ'), ('.', '.')]), Tree('S', [Tree('NP', [('Black', 'NNP')]), Tree('NP', [('comedy', 'NN')]), (',', ','), Tree('NP', [('action', 'NN')]), (',', ','), Tree('NP', [('music', 'NN')]), (',', ','), ('I', 'PRP'), ('liked', 'VBD'), Tree('NP', [('this', 'DT'), ('series', 'NN')]), ('very', 'RB'), ('much', 'RB'), ('.', '.')]), Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('happy', 'JJ'), ('to', 'TO'), Tree('NP', [('season', 'NN')]), ('2.Bravo', 'CD'), Tree('NP', [('James', 'NNP')]), Tree('NP', [('Gunn', 'NNP')]), ('!', '.')])]
#
# [Tree('S', [('When', 'WRB'), ('I', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('child', 'NN')]), ('I', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('huge', 'JJ'), ('wrestling', 'NN')]), Tree('NP', [('fan', 'NN')]), ('.', '.')]), Tree('S', [('When', 'WRB'), Tree('NP', [('the', 'DT'), ('John', 'NNP')]), Tree('NP', [('Cena', 'NNP')]), Tree('NP', [('era', 'NN')]), ('broke', 'VBD'), ('free', 'JJ'), (',', ','), ('I', 'PRP'), ('had', 'VBD'), Tree('NP', [('quit', 'NN')]), Tree('NP', [('wrestling', 'NN')]), ('to', 'TO'), Tree('NP', [('this', 'DT'), ('day', 'NN')]), ('because', 'IN'), ('of', 'IN'), Tree('NP', [('John', 'NNP')]), Tree('NP', [('Cena', 'NNP')]), ('.', '.')]), Tree('S', [('Now', 'RB'), (',', ','), Tree('NP', [('John', 'NNP')]), Tree('NP', [('Cena', 'NNP')]), ('has', 'VBZ'), ('infiltrated', 'VBN'), ('my', 'PRP$'), Tree('NP', [('superhero', 'NN')]), Tree('NP', [('genre', 'NN')]), ('.', '.')]), Tree('S', [('If', 'IN'), Tree('NP', [('John', 'NNP')]), Tree('NP', [('Cena', 'NNP')]), ('ever', 'RB'), ('beats', 'VBZ'), Tree('NP', [('legendary', 'JJ'), ('characters', 'NNS')]), ('like', 'IN'), Tree('NP', [('Aquaman', 'NNP')]), ('or', 'CC'), Tree('NP', [('Superman', 'NNP')]), ('I', 'PRP'), ("'ll", 'MD'), ('probably', 'RB'), ('lose', 'VB'), Tree('NP', [('it.About', 'NN')]), (':', ':'), ('A', 'DT'), Tree('NP', [('no', 'DT'), ('name', 'NN')]), Tree('NP', [('character', 'NN')]), ('from', 'IN'), Tree('NP', [('a', 'DT'), ('movie', 'NN')]), Tree('NP', [('reboot', 'NN')]), ('going', 'VBG'), ('through', 'IN'), Tree('NP', [('ups', 'NNS')]), ('and', 'CC'), Tree('NP', [('downs', 'NNS')]), ('of', 'IN'), Tree('NP', [('living', 'NN')]), ('in', 'IN'), Tree('NP', [('society', 'NN')]), ('.', '.')]), Tree('S', [('While', 'IN'), ('he', 'PRP'), ('kills', 'VBZ'), Tree('NP', [('people', 'NNS')]), ('in', 'IN'), Tree('NP', [('that', 'DT'), ('same', 'JJ'), ('society.Story', 'NN')]), (':', ':'), Tree('NP', [('Full', 'NN')]), ('of', 'IN'), Tree('NP', [('toilet', 'NN')]), Tree('NP', [('humour', 'NN')]), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('good', 'JJ'), ('if', 'IN'), ('you', 'PRP'), ('like', 'VBP'), Tree('NP', [('that', 'DT'), ('kind', 'NN')]), ('of', 'IN'), Tree('NP', [('stuff', 'NN')]), ('.', '.')]), Tree('S', [('You', 'PRP'), ('will', 'MD'), ('have', 'VB'), ('to', 'TO'), ('find', 'VB'), ('it', 'PRP'), ('funny', 'JJ'), ('and', 'CC'), ('great', 'JJ'), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('jokes', 'NNS')]), ('are', 'VBP'), ('out', 'IN'), ('of', 'IN'), Tree('NP', [('line', 'NN')]), (',', ','), ('but', 'CC'), ('I', 'PRP'), ('think', 'VBP'), Tree('NP', [('the', 'DT'), ('majority', 'NN')]), ('of', 'IN'), Tree('NP', [('people', 'NNS')]), ('on', 'IN'), Tree('NP', [('this', 'DT'), ('planet', 'NN')]), ('should', 'MD'), ('like', 'VB'), Tree('NP', [('the', 'DT'), ('toilet/crude', 'NN')]), Tree('NP', [('humour.Production', 'NN')]), (':', ':'), Tree('NP', [('Visuals', 'NNS')]), ('are', 'VBP'), ('outstanding', 'JJ'), ('.', '.')]), Tree('S', [('Supporting', 'VBG'), Tree('NP', [('cast', 'NN')]), ('is', 'VBZ'), ('alright', 'VBN'), ('.', '.')]), Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('just', 'RB'), ('I', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('see', 'VB'), Tree('NP', [('John', 'NNP')]), Tree('NP', [('Cena', 'NNP')]), ('.', '.')]), Tree('S', [Tree('NP', [('Jokes', 'NNS')]), ('.', '.')]), Tree('S', [('I', 'PRP'), ('see', 'VBP'), ('him', 'PRP'), ('but', 'CC'), ('what', 'WP'), ('I', 'PRP'), ('see', 'VBP'), ('is', 'VBZ'), ('generic', 'JJ'), ('and', 'CC'), Tree('NP', [('an', 'DT'), ('awful', 'JJ'), ('actor', 'NN')]), ('.', '.')]), Tree('S', [('I', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('understand', 'VB'), ('why', 'WRB'), Tree('NP', [('legendary', 'JJ'), ('characters', 'NNS')]), ('from', 'IN'), Tree('NP', [('JL', 'NNP')]), ('were', 'VBD'), ('allowed', 'VBN'), ('to', 'TO'), ('make', 'VB'), Tree('NP', [('a', 'DT'), ('cameo', 'NN')]), ('in', 'IN'), Tree('NP', [('this', 'DT'), ('show', 'NN')]), ('.', '.')]), Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), Tr ...
#
# [Tree('S', [('Maybe', 'RB'), Tree('NP', [('cause', 'NN')]), ('I', 'PRP'), ("'m", 'VBP'), Tree('NP', [('a', 'DT'), ('huge', 'JJ'), ('James', 'NNP')]), Tree('NP', [('Gunn', 'NNP')]), Tree('NP', [('fan', 'NN')]), ('and', 'CC'), ('loved', 'VBD'), Tree('NP', [('The', 'DT'), ('Suicide', 'NNP')]), Tree('NP', [('Squad', 'NNP')]), Tree('NP', [('movie', 'NN')]), ('I', 'PRP'), ('appreciate', 'VBP'), Tree('NP', [('this', 'DT'), ('series', 'NN')]), ('for', 'IN'), ('what', 'WP'), ('it', 'PRP'), ('is', 'VBZ'), ('.', '.')]), Tree('S', [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('get', 'VB'), Tree('NP', [('the', 'DT'), ('complains', 'NNS')]), ('about', 'IN'), ('the', 'DT'), ('writing', 'VBG'), ('it', 'PRP'), ("'s", 'VBZ'), ('pretty', 'JJ'), ('solid', 'JJ'), ('maybe', 'RB'), ('to', 'TO'), Tree('NP', [('much', 'JJ'), ('profanity', 'NN')]), ('otherwise', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), ('brilliant', 'JJ'), ('and', 'CC'), ('flows', 'VBZ'), ('well', 'RB'), ('!', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('music', 'NN')]), (',', ','), Tree('NP', [('cinematography', 'NN')]), (',', ','), ('and', 'CC'), Tree('NP', [('humor', 'NN')]), ('and', 'CC'), Tree('NP', [('exciting', 'JJ'), ('vibes', 'NNS')]), ('is', 'VBZ'), Tree('NP', [('all', 'DT'), ('superb', 'NN')]), ('at', 'IN'), ('least', 'JJS'), ('I', 'PRP'), ("'m", 'VBP'), ('excited', 'JJ'), ('for', 'IN'), ('more', 'RBR'), (';', ':'), ('plus', 'CC'), ('I', 'PRP'), ('crave', 'VBP'), Tree('NP', [('anything', 'NN')]), Tree('NP', [('woke', 'NN')]), ('I', 'PRP'), ('never', 'RB'), ('understand', 'VBP'), Tree('NP', [('the', 'DT'), ('ones', 'NNS')]), ('that', 'WDT'), ('bash', 'VBP'), Tree('NP', [('brilliant/bold', 'NN')]), Tree('NP', [('shows', 'NNS')]), ('or', 'CC'), Tree('NP', [('movies', 'NNS')]), ('.', '.')])]
#
# [Tree('S', [('I', 'PRP'), ('think', 'VBP'), Tree('NP', [('James', 'NNP')]), Tree('NP', [('Gunn', 'NNP')]), ('did', 'VBD'), Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('job', 'NN')]), ('of', 'IN'), ('bringing', 'VBG'), Tree('NP', [('stupidity', 'NN')]), ('and', 'CC'), Tree('NP', [('comic', 'JJ'), ('relief', 'NN')]), ('to', 'TO'), Tree('NP', [('a', 'DT'), ('non', 'NN')]), Tree('NP', [('superhero', 'NN')]), Tree('NP', [('action', 'NN')]), Tree('NP', [('series', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('casting', 'NN')]), ('of', 'IN'), Tree('NP', [('John', 'NNP')]), Tree('NP', [('Cena', 'NNP')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('one', 'NN')]), ('because', 'IN'), ('he', 'PRP'), ('can', 'MD'), ('play', 'VB'), Tree('NP', [('that', 'DT'), ('stupid', 'JJ'), ('type', 'NN')]), ('of', 'IN'), Tree('NP', [('character', 'NN')]), ('with', 'IN'), Tree('NP', [('some', 'DT'), ('muscle', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('rest', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('cast', 'NN')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('job', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Low', 'JJ'), ('end', 'NN')]), Tree('NP', [('special', 'JJ'), ('effects', 'NNS')]), ('and', 'CC'), ('80s', 'CD'), Tree('NP', [('rock', 'NN')]), ('and', 'CC'), Tree('NP', [('roll', 'NN')]), Tree('NP', [('fills', 'NNS')]), ('it', 'PRP'), ('out', 'RP'), ('.', '.')])]
#
# Licorice Pizza Movie Reviews Chunked:
# [Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('1973', 'JJ'), ('picture', 'NN')]), Tree('NP', [('day', 'NN')]), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('San', 'NNP')]), Tree('NP', [('Fernando', 'NNP')]), Tree('NP', [('Valley', 'NNP')]), Tree('NP', [('high', 'JJ'), ('school', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Gary', 'NNP')]), Tree('NP', [('Valentine', 'NNP')]), ('(', '('), Tree('NP', [('Cooper', 'NNP')]), Tree('NP', [('Hoffman', 'NNP')]), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('15', 'CD'), Tree('NP', [('year', 'NN')]), Tree('NP', [('old', 'JJ'), ('student', 'NN')]), ('and', 'CC'), Tree('NP', [('part', 'NN')]), Tree('NP', [('time', 'NN')]), Tree('NP', [('actor', 'NN')]), ('.', '.')]), Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('a', 'DT'), ('hustler', 'NN')]), ('and', 'CC'), Tree('NP', [('a', 'DT'), ('handful', 'NN')]), ('.', '.')]), Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('taken', 'VBN'), ('with', 'IN'), Tree('NP', [('Alana', 'NNP')]), Tree('NP', [('Kane', 'NNP')]), ('(', '('), Tree('NP', [('Alana', 'NNP')]), Tree('NP', [('Haim', 'NNP')]), (')', ')'), ('who', 'WP'), ('is', 'VBZ'), ('working', 'VBG'), Tree('NP', [('a', 'DT'), ('tiresome', 'JJ'), ('job', 'NN')]), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('photographer', 'NN')]), ('.', '.')]), Tree('S', [('He', 'PRP'), ('starts', 'VBZ'), ('pursuing', 'VBG'), ('her', 'PRP$'), ('despite', 'IN'), ('their', 'PRP$'), Tree('NP', [('decade', 'NN')]), Tree('NP', [('age', 'NN')]), Tree('NP', [('difference.Paul', 'NN')]), Tree('NP', [('Thomas', 'NNP')]), Tree('NP', [('Anderson', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('great', 'JJ'), ('and', 'CC'), Tree('NP', [('interesting', 'JJ'), ('filmmaker', 'NN')]), ('.', '.')]), Tree('S', [('There', 'EX'), ('is', 'VBZ'), Tree('NP', [('something', 'NN')]), ('a', 'DT'), ('little', 'JJ'), ('uncomfortable', 'JJ'), ('about', 'IN'), Tree('NP', [('the', 'DT'), ('subject', 'NN')]), Tree('NP', [('matter', 'NN')]), ('which', 'WDT'), ('keeps', 'VBZ'), ('it', 'PRP'), ('from', 'IN'), ('being', 'VBG'), ('fully', 'RB'), ('enjoyable', 'JJ'), ('and', 'CC'), ('comedic', 'JJ'), ('.', '.')]), Tree('S', [Tree('NP', [('Valentine', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('bit', 'RB'), ('much', 'JJ'), ('and', 'CC'), ('I', 'PRP'), ('feel', 'VBP'), ('the', 'DT'), ('same', 'JJ'), ('as', 'IN'), Tree('NP', [('Alana', 'NNP')]), ('.', '.')]), Tree('S', [('There', 'EX'), ('is', 'VBZ'), ('also', 'RB'), Tree('NP', [('a', 'DT'), ('couple', 'NN')]), ('of', 'IN'), Tree('NP', [('adult', 'NN')]), Tree('NP', [('characters', 'NNS')]), ('who', 'WP'), ('are', 'VBP'), ('taking', 'VBG'), Tree('NP', [('quirky', 'JJ'), ('way', 'NN')]), ('too', 'RB'), ('far', 'RB'), ('.', '.')]), Tree('S', [('Despite', 'IN'), Tree('NP', [('a', 'DT'), ('few', 'JJ'), ('bumps', 'NNS')]), ('in', 'IN'), Tree('NP', [('the', 'DT'), ('road', 'NN')]), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('a', 'DT'), ('fascinating', 'JJ'), ('ride', 'NN')]), ('done', 'VBN'), ('with', 'IN'), ('loving', 'VBG'), Tree('NP', [('nostalgia', 'NN')]), ('and', 'CC'), Tree('NP', [('visual', 'JJ'), ('skills', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('young', 'JJ'), ('performers', 'NNS')]), ('are', 'VBP'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')]), Tree('S', [Tree('NP', [('Alana', 'NNP')]), Tree('NP', [('Haim', 'NNP')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('newcomer', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('PTA', 'NNP')]), ('has', 'VBZ'), ('received', 'VBN'), ('three', 'CD'), ('more', 'JJR'), Tree('NP', [('Oscar', 'NN')]), Tree('NP', [('nominations', 'NNS')]), ('but', 'CC'), Tree('NP', [('the', 'DT'), ('odds', 'NNS')]), ('are', 'VBP'), ('against', 'IN'), ('him', 'PRP'), ('getting', 'VBG'), ('his', 'PRP$'), Tree('NP', [('first', 'JJ'), ('win', 'NN')]), ('.', '.')]), Tree('S', [('We', 'PRP'), ("'ll", 'MD'), ('see', 'VB'), ('.', '.')])]
#
# [Tree('S', [Tree('NP', [('Alana', 'NNP')]), Tree('NP', [('Haim', 'NNP')]), ('admits', 'VBZ'), ('to', 'TO'), ('being', 'VBG'), ('25', 'CD'), (',', ','), ('and', 'CC'), ('may', 'MD'), ('be', 'VB'), ('28', 'CD'), ('.', '.')]), Tree('S', [('She', 'PRP'), ('has', 'VBZ'), Tree('NP', [('no', 'DT'), ('idea', 'NN')]), ('what', 'WP'), ('she', 'PRP'), ('wants', 'VBZ'), ('to', 'TO'), ('do', 'VB'), ('.', '.')]), Tree('S', [Tree('NP', [('Cooper', 'NNP')]), Tree('NP', [('Hoffman', 'NNP')]), ('is', 'VBZ'), ('15', 'CD'), (',', ','), Tree('NP', [('a', 'DT'), ('successful', 'JJ'), ('child', 'NN')]), Tree('NP', [('actor', 'NN')]), (',', ','), Tree('NP', [('a', 'DT'), ('budding', 'NN')]), Tree('NP', [('entrepreneur', 'NN')]), ('--', ':'), Tree('NP', [('waterbeds', 'NNS')]), ('and', 'CC'), ('newly', 'RB'), ('decriminalized', 'VBN'), Tree('NP', [('pinball', 'NN')]), Tree('NP', [('machines', 'NNS')]), ('--', ':'), ('and', 'CC'), ('wants', 'VBZ'), Tree('NP', [('her.Paul', 'JJ'), ('Thomas', 'NNP')]), Tree('NP', [('Anderson', 'NNP')]), ("'s", 'POS'), ('latest', 'JJS'), Tree('NP', [('movie', 'NN')]), ('is', 'VBZ'), ('set', 'VBN'), (',', ','), ('like', 'IN'), Tree('NP', [('Tarrantino', 'NNP')]), ("'s", 'POS'), Tree('NP', [('ONCE', 'NNP')]), ('UPON', 'IN'), Tree('NP', [('A', 'NNP')]), Tree('NP', [('TIME', 'NNP')]), Tree('NP', [('IN', 'NNP')]), Tree('NP', [('HOLLYWOOD', 'NNP')]), (',', ','), ('in', 'IN'), Tree('NP', [('Los', 'NNP')]), Tree('NP', [('Angeles', 'NNP')]), Tree('NP', [('some', 'DT'), ('time', 'NN')]), ('in', 'IN'), ('the', 'DT'), ('1960s', 'CD'), ('or', 'CC'), ('1970s', 'CD'), ('--', ':'), Tree('NP', [('the', 'DT'), ('scripts', 'NNS')]), ('make', 'VBP'), ('Leave', 'VB'), ('It', 'PRP'), ('To', 'TO'), Tree('NP', [('Beaver', 'NNP')]), ('contemporaneous', 'JJ'), ('with', 'IN'), Tree('NP', [('the', 'DT'), ('Oil', 'NNP')]), Tree('NP', [('Crisis', 'NNP')]), ('.', '.')]), Tree('S', [Tree('NP', [('Anderson', 'NNP')]), ('takes', 'VBZ'), Tree('NP', [('a', 'DT'), ('viewpoint', 'NN')]), ('that', 'WDT'), ('is', 'VBZ'), ('more', 'RBR'), ('realistic', 'JJ'), (',', ','), ('more', 'RBR'), ('sympathetic', 'JJ'), (',', ','), ('and', 'CC'), ('at', 'IN'), Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]), (',', ','), ('more', 'JJR'), ('cynical', 'JJ'), ('.', '.')]), Tree('S', [('His', 'PRP$'), Tree('NP', [('camera', 'NN')]), ('looks', 'VBZ'), ('at', 'IN'), ('its', 'PRP$'), Tree('NP', [('subjects', 'NNS')]), ('like', 'IN'), ('1970s', 'CD'), Tree('NP', [('cameras', 'NNS')]), ('did', 'VBD'), (';', ':'), Tree('NP', [('people', 'NNS')]), ('are', 'VBP'), ('not', 'RB'), ('flattered', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('1970s', 'CD'), Tree('NP', [('clothes', 'NNS')]), ('they', 'PRP'), ('wear', 'VBP'), (',', ','), ('and', 'CC'), Tree('NP', [('the', 'DT'), ('visible', 'JJ'), ('architecture', 'NN')]), ('is', 'VBZ'), ('tired', 'VBN'), ('and', 'CC'), ('ugly', 'RB'), ('.', '.')]), Tree('S', [('And', 'CC'), ('no', 'DT'), ('one', 'CD'), Tree('NP', [('approves', 'NNS')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('relationship', 'NN')]), ('between', 'IN'), Tree('NP', [('the', 'DT'), ('leads', 'NNS')]), (',', ','), ('not', 'RB'), ('even', 'RB'), Tree('NP', [('Miss', 'NNP')]), Tree('NP', [('Haim.The', 'NNP')]), Tree('NP', [('movie', 'NN')]), ('is', 'VBZ'), ('filled', 'VBN'), ('out', 'RP'), ('with', 'IN'), Tree('NP', [('contemporary', 'JJ'), ('individuals', 'NNS')]), (',', ','), ('some', 'DT'), ('appearing', 'VBG'), ('under', 'IN'), ('their', 'PRP$'), Tree('NP', [('real', 'JJ'), ('names', 'NNS')]), ('--', ':'), Tree('NP', [('John', 'NNP')]), Tree('NP', [('C.', 'NNP')]), Tree('NP', [('Reilly', 'NNP')]), ('appears', 'VBZ'), ('as', 'IN'), Tree('NP', [('Fred', 'NNP')]), Tree('NP', [('Gwynne', 'NNP')]), ('in', 'IN'), Tree('NP', [('Munsters', 'NNP')]), Tree('NP', [('make-up', 'NN')]), (',', ','), ('and', 'CC'), Tree('NP', [('Bradley', 'NNP')]), Tree('NP', [('Cooper', 'NNP')]), ('as', 'IN'), Tree('NP', [('Jon', 'NNP')]), Tree('NP', [('Peters', 'NNP')]), ('--', ':'), ('while', 'IN' ...
#
# [Tree('S', [Tree('NP', [('Paul', 'NNP')]), Tree('NP', [('Thomas', 'NNP')]), Tree('NP', [('Anderson', 'NNP')]), ('takes', 'VBZ'), Tree('NP', [('an', 'DT'), ('episodic', 'JJ'), ('look', 'NN')]), ('at', 'IN'), Tree('NP', [('life', 'NN')]), ('in', 'IN'), Tree('NP', [('California', 'NNP')]), ('in', 'IN'), ('the', 'DT'), ('early', 'JJ'), ('1970s.It', 'CD'), ('is', 'VBZ'), ('through', 'IN'), Tree('NP', [('the', 'DT'), ('lens', 'NNS')]), ('of', 'IN'), ('two', 'CD'), Tree('NP', [('young', 'JJ'), ('people', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('Gary', 'NNP')]), Tree('NP', [('Valentine', 'NNP')]), ('(', '('), Tree('NP', [('Cooper', 'NNP')]), Tree('NP', [('Hoffman', 'NNP')]), (')', ')'), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('mature', 'NN')]), ('and', 'CC'), Tree('NP', [('cocky', 'NN')]), ('15', 'CD'), Tree('NP', [('year', 'NN')]), Tree('NP', [('old', 'JJ'), ('child', 'NN')]), Tree('NP', [('actor.He', 'NN')]), Tree('NP', [('charms', 'NNS')]), ('25', 'CD'), Tree('NP', [('year', 'NN')]), Tree('NP', [('old', 'JJ'), ('Alana', 'NNP')]), ('(', '('), Tree('NP', [('Alana', 'NNP')]), Tree('NP', [('Haim', 'NNP')]), (')', ')'), ('who', 'WP'), ('is', 'VBZ'), ('on', 'IN'), Tree('NP', [('the', 'DT'), ('high', 'JJ'), ('school', 'NN')]), Tree('NP', [('campus', 'NN')]), ('helping', 'VBG'), ('with', 'IN'), Tree('NP', [('the', 'DT'), ('yearbook', 'NN')]), Tree('NP', [('photos.Gary', 'JJ'), ('asks', 'NNS')]), Tree('NP', [('Alana', 'NNP')]), ('out', 'RB'), ('and', 'CC'), ('to', 'TO'), ('his', 'PRP$'), Tree('NP', [('surprise', 'NN')]), ('she', 'PRP'), ('shows', 'VBZ'), ('up', 'RP'), ('albeit', 'RB'), Tree('NP', [('reluctantly.Later', 'NN')]), Tree('NP', [('Alana', 'NNP')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('chaperone', 'NN')]), ('for', 'IN'), Tree('NP', [('Gary', 'NNP')]), ('as', 'IN'), ('he', 'PRP'), ('promotes', 'VBZ'), ('the', 'DT'), ('latest', 'JJS'), Tree('NP', [('production', 'NN')]), ('he', 'PRP'), ('is', 'VBZ'), ('appearing', 'VBG'), ('in', 'IN'), ('with', 'IN'), Tree('NP', [('the', 'DT'), ('rest', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('cast', 'NN')]), ('.', '.')]), Tree('S', [('However', 'RB'), Tree('NP', [('Gary', 'NNP')]), ('is', 'VBZ'), ('aware', 'JJ'), ('that', 'IN'), ('his', 'PRP$'), Tree('NP', [('time', 'NN')]), ('as', 'IN'), Tree('NP', [('an', 'DT'), ('actor', 'NN')]), ('is', 'VBZ'), ('nearing', 'VBG'), ('its', 'PRP$'), Tree('NP', [('end.Soon', 'NN')]), ('he', 'PRP'), ('launches', 'VBZ'), Tree('NP', [('a', 'DT'), ('new', 'JJ'), ('enterprise', 'NN')]), (',', ','), ('selling', 'VBG'), Tree('NP', [('water', 'NN')]), Tree('NP', [('beds', 'NNS')]), ('and', 'CC'), Tree('NP', [('Alana', 'NNP')]), ('helps', 'VBZ'), Tree('NP', [('out.As', 'JJ'), ('time', 'NN')]), ('goes', 'VBZ'), ('on', 'IN'), Tree('NP', [('both', 'DT'), ('mature', 'NN')]), ('and', 'CC'), Tree('NP', [('grow', 'NN')]), (',', ','), ('but', 'CC'), ('they', 'PRP'), ('also', 'RB'), ('drift', 'VBP'), ('in', 'IN'), ('and', 'CC'), ('out', 'IN'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ("'s", 'POS'), Tree('NP', [('lives.Gary', 'JJ'), ('strikes', 'NNS')]), ('up', 'RP'), Tree('NP', [('a', 'DT'), ('relationship', 'NN')]), ('with', 'IN'), Tree('NP', [('someone', 'NN')]), ('of', 'IN'), Tree('NP', [('a', 'DT'), ('similar', 'JJ'), ('age', 'NN')]), ('to', 'TO'), ('him', 'PRP'), ('.', '.')]), Tree('S', [Tree('NP', [('Alana', 'NNP')]), ('takes', 'VBZ'), Tree('NP', [('a', 'DT'), ('stab', 'NN')]), ('at', 'IN'), ('acting', 'VBG'), ('and', 'CC'), ('his', 'PRP$'), Tree('NP', [('wooed', 'NN')]), ('by', 'IN'), ('an', 'DT'), ('older', 'JJR'), Tree('NP', [('actor', 'NN')]), ('.', '.')]), Tree('S', [('Later', 'RB'), ('she', 'PRP'), ('is', 'VBZ'), ('enamoured', 'VBN'), ('with', 'IN'), Tree('NP', [('a', 'DT'), ('local', 'JJ'), ('politician.Licorice', 'NN')]), Tree('NP', [('Pizza', 'NNP')]), ('is', 'VBZ'), ('named', 'VBN'), ('after', 'IN'), ('a', 'DT'), ('now', 'RB'), Tree('NP', [('defunct', 'JJ'), ('record', 'NN')]), Tree('NP', [('store', 'NN')]), ('in', 'IN'), Tree('NP', [(' ...
#
# [Tree('S', [('What', 'WP'), ('is', 'VBZ'), Tree('NP', [('life', 'NN')]), ('?', '.')]), Tree('S', [('What', 'WP'), ('are', 'VBP'), Tree('NP', [('the', 'DT'), ('goals', 'NNS')]), ('one', 'CD'), ('sets', 'VBZ'), ('out', 'RP'), ('to', 'TO'), ('achieve', 'VB'), ('?', '.')]), Tree('S', [('What', 'WP'), ('is', 'VBZ'), Tree('NP', [('the', 'DT'), ('overall', 'JJ'), ('story', 'NN')]), ('or', 'CC'), Tree('NP', [('goal', 'NN')]), ('of', 'IN'), ('this', 'DT'), ('?', '.')]), Tree('S', [Tree('NP', [('Things', 'NNS')]), ('can', 'MD'), ('not', 'RB'), ('always', 'RB'), ('be', 'VB'), ('summed', 'VBN'), ('up', 'RP'), ('easily', 'RB'), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('movie', 'NN')]), ('(', '('), ('that', 'WDT'), ('has', 'VBZ'), Tree('NP', [('characters', 'NNS')]), ('that', 'WDT'), ('may', 'MD'), ('or', 'CC'), ('may', 'MD'), ('not', 'RB'), ('be', 'VB'), ('based', 'VBN'), ('on', 'IN'), Tree('NP', [('real', 'JJ'), ('people', 'NNS')]), (')', ')'), ('is', 'VBZ'), ('treating', 'VBG'), ('its', 'PRP$'), ('2', 'CD'), ('plus', 'CC'), Tree('NP', [('hours', 'NNS')]), ('like', 'IN'), Tree('NP', [('an', 'DT'), ('episodic', 'JJ'), ('story', 'NN')]), ('...', ':'), ('it', 'PRP'), ('begins', 'VBZ'), ('quite', 'RB'), ('romantic', 'JJ'), ('...', ':'), ('but', 'CC'), Tree('NP', [('a', 'DT'), ('love', 'NN')]), ('that', 'WDT'), ('can', 'MD'), ('not', 'RB'), ('actually', 'RB'), ('happen', 'VB'), (',', ','), ('right', 'RB'), ('?', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('age', 'NN')]), Tree('NP', [('difference', 'NN')]), ('being', 'VBG'), ('one', 'CD'), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('issues', 'NNS')]), ('...', ':'), ('and', 'CC'), Tree('NP', [('some', 'DT'), ('other', 'JJ'), ('things', 'NNS')]), ('-', ':'), Tree('NP', [('the', 'DT'), ('personalities', 'NNS')]), ('of', 'IN'), ('the', 'DT'), ('our', 'PRP$'), ('two', 'CD'), ('leads', 'VBZ'), ('to', 'TO'), ('name', 'VB'), Tree('NP', [('another', 'DT'), ('thing.And', 'NN')]), ('what', 'WP'), Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('debut', 'NN')]), ('by', 'IN'), Tree('NP', [('Alanna', 'NNP')]), Tree('NP', [('Haim', 'NNP')]), ('.', '.')]), Tree('S', [('Her', 'PRP$'), Tree('NP', [('sisters', 'NNS')]), ('are', 'VBP'), ('in', 'IN'), ('this', 'DT'), ('too', 'RB'), ('.', '.')]), Tree('S', [('Now', 'RB'), ('maybe', 'RB'), ('that', 'DT'), ('is', 'VBZ'), ('saying', 'VBG'), Tree('NP', [('something', 'NN')]), ('to', 'TO'), ('you', 'PRP'), ('(', '('), ('I', 'PRP'), ('had', 'VBD'), ('not', 'RB'), ('heard', 'VBN'), ('of', 'IN'), ('them', 'PRP'), ('or', 'CC'), ('their', 'PRP$'), Tree('NP', [('music', 'NN')]), ('I', 'PRP'), ('think', 'VBP'), (',', ','), ('though', 'IN'), ('I', 'PRP'), ('might', 'MD'), ('have', 'VB'), ('heard', 'VBN'), Tree('NP', [('a', 'DT'), ('song', 'NN')]), ('or', 'CC'), ('two', 'CD'), ('I', 'PRP'), ('reckon', 'VBP'), (')', ')'), (',', ','), ('it', 'PRP'), ('did', 'VBD'), ("n't", 'RB'), ('for', 'IN'), ('me', 'PRP'), ('and', 'CC'), Tree('NP', [('others', 'NNS')]), ('.', '.')]), Tree('S', [('But', 'CC'), ('that', 'DT'), ('does', 'VBZ'), ("n't", 'RB'), ('matter', 'VB'), ('-', ':'), ('because', 'IN'), ('her', 'PRP$'), Tree('NP', [('performance', 'NN')]), ('is', 'VBZ'), ('as', 'IN'), Tree('NP', [('genuine', 'NN')]), (',', ','), ('raw', 'JJ'), ('and', 'CC'), ('awesome', 'JJ'), ('as', 'IN'), ('it', 'PRP'), ('gets.The', 'VBZ'), Tree('NP', [('movie', 'NN')]), ('also', 'RB'), ('has', 'VBZ'), ('so', 'RB'), Tree('NP', [('many', 'JJ'), ('stars', 'NNS')]), ('in', 'IN'), ('it', 'PRP'), ('...', ':'), ('you', 'PRP'), ('may', 'MD'), ('get', 'VB'), ('lost', 'VBN'), ('.', '.')]), Tree('S', [('You', 'PRP'), ('also', 'RB'), ('may', 'MD'), ('miss', 'VB'), ('one', 'CD'), ('or', 'CC'), ('two', 'CD'), ('of', 'IN'), ('them', 'PRP'), ('.', '.')]), Tree('S', [('I', 'PRP'), ('actually', 'RB'), ('spotted', 'VBD'), ('or', 'CC'), ('rather', 'RB'), ('heard', 'JJ'), ('one', 'CD'), (',', ','), ('that', 'IN'), Tree('NP', [('the', 'DT'), ('friend', 'NN')]), ('I', 'PRP'), ('was', 'VBD'), ('with', 'IN'), ('could', 'MD' ...
#
# [Tree('S', [Tree('NP', [('The', 'DT'), ('baffling', 'NN')]), Tree('NP', [('title', 'NN')]), ('obviously', 'RB'), ('intrigued', 'VBD'), ('me', 'PRP'), (',', ','), ('but', 'CC'), Tree('NP', [('the', 'DT'), ('trailer', 'NN')]), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('film', 'NN')]), ('looked', 'VBD'), Tree('NP', [('appealing', 'NN')]), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('had', 'VBD'), Tree('NP', [('a', 'DT'), ('feeling', 'NN')]), ('it', 'PRP'), ('would', 'MD'), Tree('NP', [('some', 'DT'), ('attention', 'NN')]), ('during', 'IN'), Tree('NP', [('Awards', 'NNP')]), Tree('NP', [('Season', 'NNP')]), (',', ','), ('so', 'RB'), ('I', 'PRP'), ('went', 'VBD'), ('to', 'TO'), ('see', 'VB'), ('it', 'PRP'), (',', ','), ('written', 'VBN'), ('and', 'CC'), ('directed', 'VBN'), ('by', 'IN'), Tree('NP', [('Paul', 'NNP')]), Tree('NP', [('Thomas', 'NNP')]), Tree('NP', [('Anderson', 'NNP')]), ('(', '('), Tree('NP', [('Magnolia', 'NNP')]), (',', ','), ('There', 'EX'), ('Will', 'MD'), ('Be', 'VB'), Tree('NP', [('Blood', 'NNP')]), (',', ','), Tree('NP', [('The', 'DT'), ('Master', 'NNP')]), (')', ')'), ('.', '.')]), Tree('S', [('Basically', 'RB'), (',', ','), ('set', 'VBN'), ('in', 'IN'), Tree('NP', [('San', 'NNP')]), Tree('NP', [('Francisco', 'NNP')]), ('in', 'IN'), ('1973', 'CD'), (',', ','), ('fifteen-year-old', 'JJ'), Tree('NP', [('high', 'JJ'), ('school', 'NN')]), Tree('NP', [('Gary', 'NNP')]), Tree('NP', [('Valentine', 'NNP')]), ('(', '('), ('introducing', 'VBG'), Tree('NP', [('Golden', 'NNP')]), Tree('NP', [('Globe', 'NNP')]), ('nominated', 'VBD'), Tree('NP', [('Cooper', 'NNP')]), Tree('NP', [('Hoffman', 'NNP')]), (',', ','), Tree('NP', [('son', 'NN')]), ('of', 'IN'), Tree('NP', [('Philip', 'NNP')]), Tree('NP', [('Seymour', 'NNP')]), Tree('NP', [('Hoffman', 'NNP')]), (')', ')'), ('meets', 'VBZ'), Tree('NP', [('twenty-five-year-old', 'JJ'), ('Alana', 'NNP')]), Tree('NP', [('Kane', 'NNP')]), ('(', '('), ('introducing', 'VBG'), Tree('NP', [('Alana', 'NNP')]), Tree('NP', [('Haim', 'NNP')]), (',', ','), Tree('NP', [('vocalist', 'NN')]), ('and', 'CC'), Tree('NP', [('musician', 'NN')]), ('of', 'IN'), Tree('NP', [('pop', 'NN')]), Tree('NP', [('rock', 'NN')]), Tree('NP', [('band', 'NN')]), Tree('NP', [('Haim', 'NNP')]), (')', ')'), (',', ','), Tree('NP', [('a', 'DT'), ('photographer', 'NN')]), ("'s", 'POS'), Tree('NP', [('assistant', 'NN')]), (',', ','), ('during', 'IN'), Tree('NP', [('picture', 'NN')]), Tree('NP', [('day', 'NN')]), ('.', '.')]), Tree('S', [('He', 'PRP'), ('strikes', 'VBZ'), ('up', 'RP'), Tree('NP', [('a', 'DT'), ('conversation', 'NN')]), (',', ','), ('she', 'PRP'), ('rebuffs', 'VBD'), ('his', 'PRP$'), Tree('NP', [('advances', 'NNS')]), ('but', 'CC'), ('agrees', 'VBZ'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('dinner', 'VB'), ('and', 'CC'), ('they', 'PRP'), ('begin', 'VBP'), Tree('NP', [('a', 'DT'), ('friendship', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Gary', 'NNP')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('former', 'JJ'), ('child', 'NN')]), Tree('NP', [('actor', 'NN')]), ('and', 'CC'), ('attends', 'VBZ'), Tree('NP', [('auditions', 'NNS')]), (',', ','), Tree('NP', [('Alana', 'NNP')]), ('becomes', 'VBZ'), ('his', 'PRP$'), Tree('NP', [('chaperone', 'NN')]), (',', ','), ('when', 'WRB'), ('his', 'PRP$'), Tree('NP', [('mother', 'NN')]), ('can', 'MD'), ('not', 'RB'), ('take', 'VB'), ('him', 'PRP'), (',', ','), ('to', 'TO'), ('perform', 'VB'), ('in', 'IN'), Tree('NP', [('New', 'NNP')]), Tree('NP', [('York', 'NNP')]), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('variety', 'NN')]), Tree('NP', [('show', 'NN')]), ('with', 'IN'), Tree('NP', [('Lucy', 'NNP')]), Tree('NP', [('Doolittle', 'NNP')]), ('(', '('), Tree('NP', [('Christine', 'NNP')]), Tree('NP', [('Ebersole', 'NNP')]), (')', ')'), ('.', '.')]), Tree('S', [('On', 'IN'), Tree('NP', [('the', 'DT'), ('plane', 'NN')]), Tree('NP', [('journey', 'NN')]), Tree('NP', [('home', 'NN')]), (',', ','), Tree('NP', [('Alana', 'NNP')]), ('meets', 'VBZ'), ('one', 'CD'), ('of', 'IN'), Tree('NP ...
#
# The Marvelous Mrs Maisel Movie Reviews Chunked:
# [Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('hard', 'JJ'), ('to', 'TO'), Tree('NP', [('rate', 'NN')]), ('this', 'DT'), ('.', '.')]), Tree('S', [('After', 'IN'), ('all', 'DT'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('the', 'DT'), ('pilot', 'NN')]), Tree('NP', [('episode', 'NN')]), ('for', 'IN'), Tree('NP', [('a', 'DT'), ('new', 'JJ'), ('Amazon', 'NNP')]), Tree('NP', [('series', 'NN')]), ('and', 'CC'), Tree('NP', [('the', 'DT'), ('rest', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('episodes', 'NNS')]), ('are', 'VBP'), ('coming', 'VBG'), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('few', 'JJ'), ('weeks', 'NNS')]), ('.', '.')]), Tree('S', [('But', 'CC'), (',', ','), ('based', 'VBN'), ('on', 'IN'), ('what', 'WP'), ('I', 'PRP'), ("'ve", 'VBP'), ('seen', 'VBN'), (',', ','), ('I', 'PRP'), ('look', 'VBP'), ('forward', 'RB'), ('to', 'TO'), ('seeing', 'VBG'), ('more', 'JJR'), ('...', ':'), ('and', 'CC'), ('that', 'DT'), ('means', 'VBZ'), ('it', 'PRP'), ('is', 'VBZ'), ('an', 'DT'), ('effective', 'JJ'), ('and', 'CC'), Tree('NP', [('enjoyable', 'JJ'), ('show', 'NN')]), ('so', 'IN'), Tree('NP', [('far.The', 'JJ'), ('film', 'NN')]), ('is', 'VBZ'), ('about', 'IN'), Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('Jewish', 'NNP')]), Tree('NP', [('lady', 'NN')]), Tree('NP', [('living', 'NN')]), ('in', 'IN'), Tree('NP', [('Manhattan', 'NNP')]), ('.', '.')]), Tree('S', [('She', 'PRP'), ('thinks', 'VBZ'), ('her', 'PRP$'), Tree('NP', [('life', 'NN')]), ('is', 'VBZ'), ('pretty', 'JJ'), ('amazing', 'JJ'), ('and', 'CC'), ('it', 'PRP'), ('does', 'VBZ'), ('seem', 'VB'), Tree('NP', [('that', 'DT'), ('way', 'NN')]), ('until', 'IN'), ('she', 'PRP'), ('eventually', 'RB'), ('learns', 'VBZ'), ('that', 'IN'), ('her', 'PRP$'), Tree('NP', [('husband', 'NN')]), ('is', 'VBZ'), ('cheating', 'VBG'), ('on', 'IN'), ('her', 'PRP'), ('.', '.')]), Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('not', 'RB'), ('like', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('loss', 'NN')]), ('--', ':'), Tree('NP', [('the', 'DT'), ('guy', 'NN')]), ('seems', 'VBZ'), ('like', 'IN'), Tree('NP', [('a', 'DT'), ('real', 'JJ'), ('putz', 'NN')]), ('.', '.')]), Tree('S', [('And', 'CC'), (',', ','), ('in', 'IN'), Tree('NP', [('many', 'JJ'), ('ways', 'NNS')]), (',', ','), ('he', 'PRP'), ("'s", 'VBZ'), ('as', 'RB'), ('successful', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('is', 'VBZ'), ('due', 'JJ'), ('to', 'TO'), ('his', 'PRP$'), ('loving', 'VBG'), Tree('NP', [('wife', 'NN')]), ('...', ':'), ('but', 'CC'), Tree('NP', [('Mrs.', 'NNP')]), Tree('NP', [('Maisel', 'NNP')]), ('does', 'VBZ'), ("n't", 'RB'), ('have', 'VB'), Tree('NP', [('a', 'DT'), ('lot', 'NN')]), ('of', 'IN'), Tree('NP', [('confidence', 'NN')]), ('in', 'IN'), Tree('NP', [('herself', 'NN')]), ('and', 'CC'), ('her', 'PRP$'), Tree('NP', [('ability', 'NN')]), ('to', 'TO'), ('live', 'VB'), ('without', 'IN'), ('him', 'PRP'), ('.', '.')]), Tree('S', [('Overall', 'JJ'), (',', ','), Tree('NP', [('a', 'DT'), ('clever', 'NN')]), Tree('NP', [('show', 'NN')]), ('and', 'CC'), ('one', 'CD'), ('that', 'WDT'), ('is', 'VBZ'), ('wholly', 'RB'), ('original', 'JJ'), ('and', 'CC'), ('enjoyable', 'JJ'), ('.', '.')]), Tree('S', [('So', 'RB'), ('far', 'RB'), (',', ','), ('so', 'RB'), ('good', 'JJ'), ('.', '.')])]
#
# [Tree('S', [('I', 'PRP'), ('watched', 'VBD'), ('all', 'DT'), ('of', 'IN'), Tree('NP', [('season', 'NN')]), ('1', 'CD'), (',', ','), ('but', 'CC'), Tree('NP', [('season', 'NN')]), ('2', 'CD'), ('was', 'VBD'), ('not', 'RB'), ('so', 'RB'), ('interesting', 'JJ'), ('and', 'CC'), ('I', 'PRP'), ('failed', 'VBD'), ('to', 'TO'), ('watch', 'VB'), Tree('NP', [('all', 'DT'), ('episodes', 'NNS')]), ('.', '.')]), Tree('S', [('But', 'CC'), ('now', 'RB'), (',', ','), ('2019', 'CD'), ('in', 'IN'), Tree('NP', [('season', 'NN')]), ('3', 'CD'), (',', ','), ('I', 'PRP'), ('am', 'VBP'), ('hooked', 'JJ'), ('again', 'RB'), ('.', '.')]), Tree('S', [('It', 'PRP'), ('is', 'VBZ'), ('1960', 'CD'), ('and', 'CC'), Tree('NP', [('Midge', 'NNP')]), ('is', 'VBZ'), ('branching', 'VBG'), ('out', 'RP'), ('to', 'TO'), ('do', 'VB'), Tree('NP', [('shows', 'NNS')]), ('outside', 'IN'), ('of', 'IN'), Tree('NP', [('Manhattan', 'NNP')]), (',', ','), ('and', 'CC'), ('even', 'RB'), ('goes', 'VBZ'), ('to', 'TO'), ('Vegas', 'VB'), ('to', 'TO'), ('work', 'VB'), ('with', 'IN'), ('a', 'DT'), ('more', 'RBR'), Tree('NP', [('well-known', 'JJ'), ('entertainer', 'NN')]), (',', ','), Tree('NP', [('a', 'DT'), ('fictional', 'JJ'), ('singer', 'NN')]), (',', ','), Tree('NP', [('Shy', 'NNP')]), Tree('NP', [('Baldwin.I', 'NNP')]), ('watch', 'VBP'), Tree('NP', [('the', 'DT'), ('show', 'NN')]), ('because', 'IN'), Tree('NP', [('Rachel', 'NNP')]), Tree('NP', [('Brosnahan', 'NNP')]), ('is', 'VBZ'), ('so', 'RB'), ('good', 'JJ'), ('as', 'IN'), Tree('NP', [('Mrs.', 'NNP')]), Tree('NP', [('Maisel', 'NNP')]), (',', ','), Tree('NP', [("'Midge", 'NNP')]), ("'", 'POS'), ('.', '.')]), Tree('S', [('She', 'PRP'), ('is', 'VBZ'), ('far', 'RB'), ('from', 'IN'), ('perfect', 'JJ'), (',', ','), ('she', 'PRP'), ('gets', 'VBZ'), ('divorced', 'VBN'), ('and', 'CC'), ('does', 'VBZ'), ("n't", 'RB'), ('seem', 'VB'), ('to', 'TO'), ('care', 'VB'), ('much', 'JJ'), ('what', 'WP'), ('happens', 'VBZ'), ('to', 'TO'), ('her', 'PRP$'), ('two', 'CD'), Tree('NP', [('kids', 'NNS')]), (',', ','), ('often', 'RB'), ('being', 'VBG'), ('cared', 'VBN'), ('for', 'IN'), ('by', 'IN'), Tree('NP', [('the', 'DT'), ('grandparents', 'NNS')]), ('who', 'WP'), ('have', 'VBP'), ('their', 'PRP$'), Tree('NP', [('own', 'JJ'), ('issues', 'NNS')]), ('.', '.')]), Tree('S', [('I', 'PRP'), ('really', 'RB'), ('like', 'IN'), Tree('NP', [('Tony', 'NNP')]), Tree('NP', [('Shalhoub', 'NNP')]), ('as', 'IN'), ('her', 'PRP$'), Tree('NP', [('dad', 'NN')]), (',', ','), Tree('NP', [('Professor', 'NNP')]), Tree('NP', [('Abe', 'NNP')]), Tree('NP', [('Weissman.Also', 'NNP')]), ('really', 'RB'), ('good', 'JJ'), ('is', 'VBZ'), Tree('NP', [('Alex', 'NNP')]), Tree('NP', [('Borstein', 'NNP')]), ('as', 'IN'), ('short', 'JJ'), (',', ','), Tree('NP', [('spineless', 'JJ'), ('Susie', 'NNP')]), Tree('NP', [('Myerson', 'NNP')]), (',', ','), Tree('NP', [('a', 'DT'), ('friend', 'NN')]), ('who', 'WP'), ('serves', 'VBZ'), ('as', 'IN'), ('her', 'PRP$'), Tree('NP', [('manager', 'NN')]), (',', ','), ('rarely', 'RB'), ('taking', 'VBG'), Tree('NP', [('a', 'DT'), ('strong', 'JJ'), ('stand', 'NN')]), ('on', 'IN'), Tree('NP', [('anything', 'NN')]), ('but', 'CC'), ('needs', 'VBZ'), ('the', 'DT'), ('10', 'CD'), Tree('NP', [('%', 'NN')]), ('she', 'PRP'), ('gets', 'VBZ'), ('from', 'IN'), ('her', 'PRP$'), Tree('NP', [('clients', 'NNS')]), ('.', '.')]), Tree('S', [('She', 'PRP'), ('has', 'VBZ'), ('a', 'DT'), ('very', 'RB'), Tree('NP', [('funny', 'JJ'), ('style', 'NN')]), ('about', 'IN'), ('her', 'PRP'), (',', ','), ('her', 'PRP$'), Tree('NP', [('character', 'NN')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('goofball', 'NN')]), ('in', 'IN'), ('a', 'DT'), ('very', 'RB'), Tree('NP', [('nice', 'JJ'), ('way', 'NN')]), ('.', '.')]), Tree('S', [('But', 'CC'), ('I', 'PRP'), ('also', 'RB'), ('must', 'MD'), ('say', 'VB'), ('her', 'PRP$'), Tree('NP', [('overly', 'JJ'), ('dirty', 'NN')]), Tree('NP', [('mouth', 'NN')]), ('gets', 'VBZ'), Tree('NP', [('tiresome', 'JJ'), ('quickly.The', 'NN')]), Tree('NP', [('late-1 ...
#
# [Tree('S', [('Was', 'VBP'), ("n't", 'RB'), ('streaming', 'VBG'), ('supposed', 'VBN'), ('to', 'TO'), ('usher', 'VB'), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('new', 'JJ'), ('universe', 'NN')]), ('where', 'WRB'), ('shows', 'VBZ'), ('got', 'VBD'), ('better', 'RB'), ('over', 'IN'), Tree('NP', [('time', 'NN')]), ('without', 'IN'), Tree('NP', [('the', 'DT'), ('network', 'NN')]), Tree('NP', [('watchdogs', 'NNS')]), ('on', 'IN'), ('their', 'PRP$'), Tree('NP', [('heels', 'NNS')]), ('?', '.')]), Tree('S', [Tree('NP', [('First', 'NNP')]), Tree('NP', [('season', 'NN')]), Tree('NP', [('brilliant', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Awards', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('Prestige', 'NNP')]), ('.', '.')]), Tree('S', [Tree('NP', [('Double', 'NNP')]), Tree('NP', [('everyone', 'NN')]), ("'s", 'POS'), Tree('NP', [('salary', 'NN')]), ('.', '.')]), Tree('S', [('Learn', 'VB'), ('how', 'WRB'), ('to', 'TO'), ('graciously', 'RB'), ('accept', 'VB'), Tree('NP', [('awards', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('Second', 'JJ'), ('season', 'NN')]), ('did', 'VBD'), ('not', 'RB'), ('raise', 'VB'), Tree('NP', [('the', 'DT'), ('bar', 'NN')]), ('but', 'CC'), ('thankfully', 'RB'), ('held', 'VBD'), ('it', 'PRP'), ('.', '.')]), Tree('S', [Tree('NP', [('Third', 'NNP')]), Tree('NP', [('season', 'NN')]), Tree('NP', [('cringe-worthy', 'NN')]), (',', ','), Tree('NP', [('episodes', 'NNS')]), ('so', 'IN'), ('off-track', 'JJ'), ('you', 'PRP'), ('will', 'MD'), ('wear', 'VB'), ('out', 'RP'), Tree('NP', [('the', 'DT'), ('fast', 'JJ'), ('forward', 'NN')]), Tree('NP', [('button', 'NN')]), ('.', '.')]), Tree('S', [('As', 'IN'), ('if', 'IN'), Tree('NP', [('the', 'DT'), ('writers/producers', 'NNS')]), ('developed', 'VBD'), Tree('NP', [('amnesia', 'NN')]), ('and', 'CC'), ('forgot', 'VBD'), ('what', 'WP'), ('made', 'VBD'), Tree('NP', [('the', 'DT'), ('show', 'NN')]), Tree('NP', [('a', 'DT'), ('hit', 'NN')]), ('in', 'IN'), Tree('NP', [('the', 'DT'), ('first', 'JJ'), ('place', 'NN')]), ('.', '.')])]
#
# [Tree('S', [('Captivating', 'VBG'), ('well', 'RB'), ('deserving', 'VBG'), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('awards', 'NNS')]), ('it', 'PRP'), ("'s", 'VBZ'), ('earned', 'VBN'), ('!', '.')]), Tree('S', [Tree('NP', [('Poignant', 'JJ'), ('delight', 'NN')]), ('and', 'CC'), ('heartwarming', 'VBG'), ('constantly', 'RB'), ('!', '.')]), Tree('S', [Tree('NP', [('Rachel', 'NNP')]), Tree('NP', [('Brosnahan', 'NNP')]), ('and', 'CC'), Tree('NP', [('Alex', 'NNP')]), Tree('NP', [('Borstein', 'NNP')]), ('are', 'VBP'), ('lovely', 'RB'), (';', ':'), Tree('NP', [('Rachel', 'NNP')]), ('is', 'VBZ'), ('gorgeous', 'JJ'), ('I', 'PRP'), ('love', 'VBP'), ('her', 'PRP'), ('.', '.')]), Tree('S', [('I', 'PRP'), ('bet', 'RB'), Tree('NP', [('Marvelous', 'NNP')]), Tree('NP', [('Mrs.', 'NNP')]), Tree('NP', [('Maisel', 'NNP')]), ('is', 'VBZ'), ('quite', 'RB'), Tree('NP', [('a', 'DT'), ('feat', 'NN')]), ('to', 'TO'), ('make', 'VB'), ('in', 'IN'), Tree('NP', [('many', 'JJ'), ('aspects', 'NNS')]), ('like', 'IN'), Tree('NP', [('the', 'DT'), ('writing', 'NN')]), (',', ','), ('set', 'VBN'), Tree('NP', [('designs', 'NNS')]), (',', ','), Tree('NP', [('clothing', 'NN')]), (',', ','), ('and', 'CC'), Tree('NP', [('choreography', 'NN')]), ('.', '.')]), Tree('S', [('Very', 'RB'), ('enjoyable', 'JJ'), ('I', 'PRP'), ("'m", 'VBP'), ('I', 'PRP'), ('decided', 'VBD'), ('to', 'TO'), ('watch', 'VB'), Tree('NP', [('season', 'NN')]), ('3', 'CD'), ('.', '.')])]
#
# [Tree('S', [('I', 'PRP'), ('really', 'RB'), ('enjoyed', 'VBD'), Tree('NP', [('this', 'DT'), ('tv', 'NN')]), Tree('NP', [('series', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('story', 'NN')]), ('was', 'VBD'), ('simple', 'JJ'), (',', ','), ('but', 'CC'), ('really', 'RB'), ('interesting', 'JJ'), ('and', 'CC'), ('entertaining', 'JJ'), ('.', '.')]), Tree('S', [('The', 'DT'), ('leading', 'VBG'), Tree('NP', [('lady', 'NN')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('delight', 'NN')]), ('as', 'RB'), ('well', 'RB'), ('.', '.')]), Tree('S', [('Actually', 'RB'), (',', ','), ('she', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('one', 'CD'), ('supporting', 'VBG'), Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('drama', 'NN')]), ('.', '.')]), Tree('S', [('A', 'DT'), ('one', 'CD'), Tree('NP', [('woman', 'NN')]), Tree('NP', [('show', 'NN')]), ('really', 'RB'), ('.', '.')]), Tree('S', [Tree('NP', [('Ca', 'NNP')]), ("n't", 'RB'), ('wait', 'VBD'), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('second', 'JJ'), ('season', 'NN')]), ('.', '.')])]
#
# Space Force Movie Reviews Chunked:
# [Tree('S', [('I', 'PRP'), ('love', 'VBP'), ('steve', 'RB'), Tree('NP', [('carell', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('i', 'NN')]), ('love', 'VBP'), Tree('NP', [('the', 'DT'), ('office', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('i', 'NN')]), ('hate', 'VBP'), Tree('NP', [('space', 'NN')]), Tree('NP', [('force', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('a', 'DT'), ('lot', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('i', 'NN')]), ('watched', 'VBD'), ('2', 'CD'), Tree('NP', [('episodes', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('i', 'NN')]), ('laughed', 'VBD'), ('about', 'RB'), ('1.5', 'CD'), Tree('NP', [('times', 'NNS')]), ('total', 'JJ'), ('.', '.')]), Tree('S', [Tree('NP', [('i', 'NN')]), ('had', 'VBD'), ('to', 'TO'), ('convince', 'VB'), ('myself', 'PRP'), ('to', 'TO'), ('even', 'RB'), ('finish', 'VB'), Tree('NP', [('the', 'DT'), ('second', 'JJ'), ('episode', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('the', 'DT'), ('majority', 'NN')]), ('of', 'IN'), ('the', 'DT'), ('two', 'CD'), Tree('NP', [('episodes', 'NNS')]), ('had', 'VBD'), ('me', 'PRP'), ('with', 'IN'), Tree('NP', [('a', 'DT'), ('straight', 'JJ'), ('deadpan', 'NN')]), Tree('NP', [('face', 'NN')]), (',', ','), ('not', 'RB'), ('even', 'RB'), Tree('NP', [('a', 'DT'), ('smile', 'NN')]), ('at', 'IN'), Tree('NP', [('the', 'DT'), ('lame', 'NN')]), Tree('NP', [('jokes', 'NNS')]), ('that', 'WDT'), ('were', 'VBD'), ('on', 'IN'), Tree('NP', [('display', 'NN')]), ('.', '.')]), Tree('S', [('and', 'CC'), ('on', 'IN'), Tree('NP', [('top', 'NN')]), ('of', 'IN'), ('that', 'DT'), (',', ','), ('it', 'PRP'), ('felt', 'VBD'), ('stupid', 'JJ'), (',', ','), ('factory-assembled', 'JJ'), (',', ','), ('and', 'CC'), ('reeked', 'VBD'), ('of', 'IN'), Tree('NP', [('netflix', 'JJ'), ('inferiority', 'NN')]), ('(', '('), ('1', 'CD'), Tree('NP', [('viewing', 'NN')]), (',', ','), ('6/25/2020', 'CD'), (')', ')')])]
#
# ...
# [Tree('S', [('...', ':'), ('from', 'IN'), Tree('NP', [('the', 'DT'), ('fans', 'NNS')]), ('of', 'IN'), Tree('NP', [('James', 'NNP')]), Tree('NP', [('Bond', 'NNP')]), ('to', 'TO'), Tree('NP', [('the', 'DT'), ('admirers', 'NNS')]), ('of', 'IN'), Tree('NP', [('Michael', 'NNP')]), Tree('NP', [('Caine', 'NNP')]), ('or', 'CC'), Tree('NP', [('Colin', 'NNP')]), Tree('NP', [('Firth', 'NNP')]), ('.', '.')]), Tree('S', [('from', 'IN'), Tree('NP', [('the', 'DT'), ('Kick', 'NNP')]), Tree('NP', [('Ass', 'NNP')]), Tree('NP', [('admirers', 'NNS')]), ('to', 'TO'), ('video', 'VB'), Tree('NP', [('games', 'NNS')]), Tree('NP', [('fans', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('a', 'DT'), ('film', 'NN')]), ('like', 'IN'), Tree('NP', [('a', 'DT'), ('huge', 'JJ'), ('mall', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('a', 'DT'), ('sort', 'NN')]), ('of', 'IN'), Tree('NP', [('candy', 'NN')]), Tree('NP', [('shop', 'NN')]), ('.', '.')]), Tree('S', [('seductive', 'JJ'), (',', ','), ('with', 'IN'), ('few', 'JJ'), Tree('NP', [('significant', 'JJ'), ('holes', 'NNS')]), (',', ','), ('mixing', 'VBG'), Tree('NP', [('secret', 'JJ'), ('service', 'NN')]), ('with', 'IN'), Tree('NP', [('Kill', 'NNP')]), Tree('NP', [('Bill', 'NNP')]), ('and', 'CC'), ('giving', 'VBG'), (',', ','), ('as', 'IN'), ('the', 'DT'), ('most', 'RBS'), Tree('NP', [('significant', 'JJ'), ('presence', 'NN')]), Tree('NP', [('a', 'DT'), ('crazy', 'JJ'), ('performance', 'NN')]), ('from', 'IN'), Tree('NP', [('Samuel', 'NNP')]), Tree('NP', [('L.', 'NNP')]), Tree('NP', [('Jackson', 'NNP')]), ('remembering', 'VBG'), Tree('NP', [('the', 'DT'), ('cinema', 'NN')]), ('of', 'IN'), Tree('NP', [('Quentin', 'NNP')]), Tree('NP', [('Tarantino', 'NNP')]), ('.', '.')]), Tree('S', [('sure', 'RB'), (',', ','), Tree('NP', [('the', 'DT'), ('revelation', 'NN')]), ('is', 'VBZ'), Tree('NP', [('the', 'DT'), ('young', 'JJ'), ('Taron', 'NNP')]), Tree('NP', [('Egerton', 'NNP')]), ('.', '.')]), Tree('S', [('but', 'CC'), Tree('NP', [('the', 'DT'), ('basic', 'JJ'), ('virtue', 'NN')]), ('of', 'IN'), Tree('NP', [('film', 'NN')]), ('could', 'MD'), ('be', 'VB'), ('its', 'PRP$'), Tree('NP', [('humor', 'NN')]), ('.', '.')]), Tree('S', [('and', 'CC'), ('its', 'PRP$'), ('...', ':'), Tree('NP', [('modesty', 'NN')]), ('.', '.')]), Tree('S', [('because', 'IN'), Tree('NP', [('the', 'DT'), ('fun', 'NN')]), ('is', 'VBZ'), Tree('NP', [('the', 'DT'), ('precise', 'JJ'), ('tool', 'NN')]), ('for', 'IN'), Tree('NP', [('save', 'NN')]), Tree('NP', [('a', 'DT'), ('film', 'NN')]), ('for', 'IN'), ('a', 'DT'), ('public', 'JJ'), ('looking', 'VBG'), ('for', 'IN'), Tree('NP', [('sensations', 'NNS')]), ('.', '.')])]
#
# [Tree('S', [('So', 'RB'), ('far', 'RB'), ('it', 'PRP'), ("'s", 'VBZ'), ('been', 'VBN'), ('rare', 'JJ'), ('to', 'TO'), ('see', 'VB'), Tree('NP', [('deaf', 'JJ'), ('characters', 'NNS')]), ('portrayed', 'VBD'), ('onscreen', 'JJ'), (',', ','), ('let', 'VB'), ('alone', 'RB'), ('played', 'VBN'), ('by', 'IN'), Tree('NP', [('deaf', 'JJ'), ('actors', 'NNS')]), ('.', '.')]), Tree('S', [('That', 'DT'), ('makes', 'VBZ'), Tree('NP', [('Sian', 'JJ'), ('Heder', 'NNP')]), ("'s", 'POS'), Tree('NP', [('Academy', 'NNP')]), Tree('NP', [('Award-nominated', 'NNP')]), ('``', '``'), Tree('NP', [('CODA', 'NNP')]), ("''", "''"), ('all', 'PDT'), ('the', 'DT'), ('more', 'RBR'), ('important', 'JJ'), ('.', '.')]), Tree('S', [('Showing', 'VBG'), Tree('NP', [('the', 'DT'), ('challenges', 'NNS')]), ('that', 'IN'), Tree('NP', [('a', 'DT'), ('hearing', 'NN')]), Tree('NP', [('daughter', 'NN')]), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('deaf', 'JJ'), ('family', 'NN')]), ('faces', 'VBZ'), (',', ','), ('it', 'PRP'), ('hits', 'VBZ'), ('all', 'PDT'), Tree('NP', [('the', 'DT'), ('right', 'JJ'), ('notes', 'NNS')]), ('(', '('), ('pun', 'IN'), ('not', 'RB'), ('intended', 'VBN'), (')', ')'), ('.Another', 'RB'), Tree('NP', [('good', 'JJ'), ('movie', 'NN')]), ('about', 'IN'), Tree('NP', [('the', 'DT'), ('daughter', 'NN')]), ('of', 'IN'), Tree('NP', [('deaf', 'NN')]), Tree('NP', [('parents', 'NNS')]), ('is', 'VBZ'), Tree('NP', [('the', 'DT'), ('German', 'JJ'), ('movie', 'NN')]), ('``', '``'), Tree('NP', [('Beyond', 'NNP')]), Tree('NP', [('Silence', 'NNP')]), ("''", "''"), ('.', '.')])]
#
# [Tree('S', [('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('and', 'CC'), Tree('NP', [('heart', 'NN')]), Tree('NP', [('warming', 'NN')]), Tree('NP', [('film', 'NN')]), ('about', 'IN'), Tree('NP', [('a', 'DT'), ('teenage', 'JJ'), ('girl', 'NN')]), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('marginalised', 'JJ'), ('family', 'NN')]), ('.', '.')]), Tree('S', [('I', 'PRP'), ('am', 'VBP'), ('very', 'RB'), ('happy', 'JJ'), ('that', 'IN'), Tree('NP', [('someone', 'NN')]), ('made', 'VBD'), Tree('NP', [('a', 'DT'), ('film', 'NN')]), ('about', 'IN'), Tree('NP', [('the', 'DT'), ('challenges', 'NNS')]), ('of', 'IN'), ('a', 'DT'), ('marginalised', 'JJ'), ('and', 'CC'), Tree('NP', [('forgotten', 'JJ'), ('group', 'NN')]), ('.', '.')])]
#
# [Tree('S', [('For', 'IN'), ('most', 'JJS'), ('of', 'IN'), Tree('NP', [('CODA', 'NNP')]), ("'s", 'POS'), Tree('NP', [('running', 'NN')]), Tree('NP', [('time', 'NN')]), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ('enjoying', 'VBG'), ('it', 'PRP'), ('very', 'RB'), ('much', 'RB'), ('while', 'IN'), ('at', 'IN'), Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]), ('thinking', 'VBG'), ('that', 'IN'), ('it', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('very', 'RB'), ('safe', 'JJ'), (',', ','), ('made', 'VBN'), ('for', 'IN'), Tree('NP', [('television', 'NN')]), Tree('NP', [('movie', 'NN')]), Tree('NP', [('vibe', 'NN')]), ('that', 'WDT'), ('was', 'VBD'), ('keeping', 'VBG'), ('it', 'PRP'), ('from', 'IN'), Tree('NP', [('greatness', 'NN')]), ('.', '.')]), Tree('S', [('But', 'CC'), ('then', 'RB'), ('there', 'EX'), ('was', 'VBD'), ('that', 'IN'), Tree('NP', [('audition', 'JJ'), ('scene', 'NN')]), ('.', '.')]), Tree('S', [('If', 'IN'), ('you', 'PRP'), ("'ve", 'VBP'), ('seen', 'VBN'), Tree('NP', [('the', 'DT'), ('movie', 'NN')]), (',', ','), ('you', 'PRP'), ('know', 'VBP'), ('what', 'WP'), ('I', 'PRP'), ("'m", 'VBP'), ('talking', 'VBG'), ('about', 'IN'), ('.', '.')]), Tree('S', [('And', 'CC'), ('from', 'IN'), Tree('NP', [('that', 'DT'), ('moment', 'NN')]), ('forward', 'RB'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('mess', 'NN')]), ('.', '.')]), Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('obsessed', 'JJ'), ('with', 'IN'), Tree('NP', [('Emilia', 'NNP')]), Tree('NP', [('Jones', 'NNP')]), ("'s", 'POS'), Tree('NP', [('version', 'NN')]), ('of', 'IN'), ('``', '``'), Tree('NP', [('Both', 'DT'), ('Sides', 'NNP')]), ('Now', 'RB'), ("''", "''"), ('on', 'IN'), Tree('NP', [('Spotify', 'NNP')]), (',', ','), ('and', 'CC'), ('I', 'PRP'), ("'m", 'VBP'), ('already', 'RB'), ('dreading', 'VBG'), Tree('NP', [('the', 'DT'), ('day', 'NN')]), ('I', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('send', 'VB'), ('my', 'PRP$'), Tree('NP', [('son', 'NN')]), ('off', 'IN'), ('to', 'TO'), Tree('NP', [('college', 'NN')]), ('(', '('), ('he', 'PRP'), ("'s", 'VBZ'), ('12', 'CD'), (',', ','), ('by', 'IN'), Tree('NP', [('the', 'DT'), ('way', 'NN')]), (')', ')'), ('.This', 'FW'), Tree('NP', [('movie', 'NN')]), ('is', 'VBZ'), ('warm', 'JJ'), ('and', 'CC'), ('earnest', 'JJS'), ('in', 'IN'), ('the', 'DT'), ('best', 'JJS'), Tree('NP', [('possible', 'JJ'), ('way', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Jones', 'NNP')]), ('gives', 'VBZ'), Tree('NP', [('a', 'DT'), ('marvelous', 'JJ'), ('performance', 'NN')]), ('--', ':'), ('it', 'PRP'), ("'s", 'VBZ'), ('too', 'RB'), ('bad', 'JJ'), ('she', 'PRP'), ('could', 'MD'), ("n't", 'RB'), ('have', 'VB'), ('received', 'VBN'), ('more', 'JJR'), Tree('NP', [('recognition', 'NN')]), ('for', 'IN'), ('this', 'DT'), ('.', '.')]), Tree('S', [('And', 'CC'), Tree('NP', [('Marlee', 'NNP')]), Tree('NP', [('Matlin', 'NNP')]), ('and', 'CC'), Tree('NP', [('Troy', 'NNP')]), Tree('NP', [('Kotsur', 'NNP')]), ('give', 'VB'), ('equally', 'RB'), Tree('NP', [('wonderful', 'JJ'), ('performances', 'NNS')]), ('as', 'IN'), Tree('NP', [('Jones', 'NNP')]), ("'s", 'POS'), Tree('NP', [('parents', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('A', 'DT'), ('scene', 'NN')]), ('where', 'WRB'), Tree('NP', [('Matlin', 'NNP')]), ('tells', 'VBZ'), Tree('NP', [('Jones', 'NNP')]), ('that', 'IN'), ('she', 'PRP'), ('was', 'VBD'), ('disappointed', 'VBN'), ('when', 'WRB'), ('she', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('born', 'VBN'), Tree('NP', [('deaf', 'NN')]), (',', ','), ('and', 'CC'), ('another', 'DT'), ('where', 'WRB'), Tree('NP', [('Kotsur', 'NNP')]), ('has', 'VBZ'), ('his', 'PRP$'), Tree('NP', [('daughter', 'NN')]), ('sing', 'VBG'), ('to', 'TO'), ('him', 'PRP'), ('while', 'IN'), ('he', 'PRP'), ('feels', 'VBZ'), ('her', 'PRP$'), Tree('NP', [('throat', 'NN')]), ('are', 'VBP'), ('two', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('devastating', 'JJ'), ('you', 'PRP'), ("'ll", 'MD'), ('see', 'VB'), ('in', 'IN'), Tree('NP', [('movies', 'NNS')]), T ...
#
# [Tree('S', [Tree('NP', [('Greetings', 'NNS')]), ('again', 'RB'), ('from', 'IN'), Tree('NP', [('the', 'DT'), ('darkness', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Ruby', 'NNP')]), Tree('NP', [('Rossi', 'NNP')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('high', 'JJ'), ('school', 'NN')]), Tree('NP', [('student', 'NN')]), ('.', '.')]), Tree('S', [('She', 'PRP'), ('is', 'VBZ'), ('also', 'RB'), Tree('NP', [('a', 'DT'), ('CODA', 'NNP')]), ('-', ':'), Tree('NP', [('Child', 'NN')]), ('of', 'IN'), Tree('NP', [('Deaf', 'NNP')]), Tree('NP', [('Adults', 'NNP')]), ('.', '.')]), Tree('S', [('Her', 'PRP$'), ('older', 'JJR'), Tree('NP', [('brother', 'NN')]), ('is', 'VBZ'), ('deaf', 'RB'), ('too', 'RB'), (',', ','), ('meaning', 'VBG'), Tree('NP', [('Ruby', 'NNP')]), ("'s", 'POS'), Tree('NP', [('life', 'NN')]), ('has', 'VBZ'), ('been', 'VBN'), ('spent', 'VBN'), ('as', 'IN'), Tree('NP', [('an', 'DT'), ('interpreter', 'NN')]), ('for', 'IN'), ('her', 'PRP$'), Tree('NP', [('family', 'NN')]), (',', ','), ('while', 'IN'), ('also', 'RB'), ('working', 'VBG'), ('on', 'IN'), Tree('NP', [('the', 'DT'), ('family', 'NN')]), ('fishing', 'VBG'), Tree('NP', [('boat', 'NN')]), ('in', 'IN'), Tree('NP', [('Gloucester', 'NNP')]), (',', ','), Tree('NP', [('Massachusetts', 'NNP')]), (',', ','), ('where', 'WRB'), ('they', 'PRP'), ('are', 'VBP'), ('treated', 'VBN'), ('as', 'IN'), Tree('NP', [('outcasts', 'NNS')]), ('and', 'CC'), ('viewed', 'VBN'), ('as', 'IN'), Tree('NP', [('oddities', 'NNS')]), ('by', 'IN'), Tree('NP', [('others', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('Ruby', 'NNP')]), ('also', 'RB'), ('loves', 'VBZ'), ('to', 'TO'), ('sing', 'VB'), ('and', 'CC'), ('listen', 'VB'), ('to', 'TO'), Tree('NP', [('music', 'NN')]), (',', ','), Tree('NP', [('activities', 'NNS')]), ('she', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), Tree('NP', [('share', 'NN')]), ('with', 'IN'), ('her', 'PRP$'), Tree('NP', [('family', 'NN')]), ('.', '.')]), Tree('S', [('This', 'DT'), ('is', 'VBZ'), Tree('NP', [('no', 'DT'), ('coming-of-age', 'JJ'), ('tale', 'NN')]), (',', ','), ('as', 'IN'), Tree('NP', [('Ruby', 'NNP')]), ('has', 'VBZ'), ('long', 'RB'), ('been', 'VBN'), ('wise', 'JJ'), ('beyond', 'IN'), ('her', 'PRP$'), Tree('NP', [('years', 'NNS')]), ('.', '.')]), Tree('S', [('It', 'PRP'), ('is', 'VBZ'), (',', ','), ('however', 'RB'), (',', ','), Tree('NP', [('a', 'DT'), ('story', 'NN')]), ('of', 'IN'), Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('person', 'NN')]), ('finding', 'VBG'), ('their', 'PRP$'), Tree('NP', [('true', 'JJ'), ('self', 'NN')]), ('and', 'CC'), ('breaking', 'VBG'), ('from', 'IN'), Tree('NP', [('the', 'DT'), ('ties', 'NNS')]), ('that', 'WDT'), ('bind', 'VBP'), ('to', 'TO'), Tree('NP', [('the', 'DT'), ('only', 'JJ'), ('life', 'NN')]), ('she', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('known.Emilia', 'JJ'), ('Jones', 'NNP')]), ('(', '('), Tree('NP', [('HIGH-RISE', 'NNP')]), (',', ','), ('2015', 'CD'), (')', ')'), ('stars', 'VBZ'), ('as', 'IN'), Tree('NP', [('Ruby', 'NNP')]), (',', ','), ('and', 'CC'), ('we', 'PRP'), ('first', 'RB'), ('see', 'VB'), ('her', 'PRP'), ('slinging', 'VBG'), ('fish', 'JJ'), ('on', 'IN'), Tree('NP', [('the', 'DT'), ('boat', 'NN')]), ('with', 'IN'), ('her', 'PRP$'), Tree('NP', [('father', 'NN')]), Tree('NP', [('Frank', 'NNP')]), ('(', '('), Tree('NP', [('Troy', 'NNP')]), Tree('NP', [('Kutsor', 'NNP')]), (')', ')'), ('and', 'CC'), ('brother', '$'), Tree('NP', [('Leo', 'NNP')]), ('(', '('), Tree('NP', [('newcomer', 'JJ'), ('Daniel', 'NNP')]), Tree('NP', [('Durant', 'NNP')]), (')', ')'), ('.', '.')]), Tree('S', [Tree('NP', [('Ruby', 'NNP')]), Tree('NP', [('belts', 'NNS')]), ('out', 'RP'), Tree('NP', [('songs', 'NNS')]), ('while', 'IN'), ('the', 'DT'), ('two', 'CD'), Tree('NP', [('men', 'NNS')]), ('handle', 'VBP'), ('their', 'PRP$'), Tree('NP', [('duties', 'NNS')]), (',', ','), Tree('NP', [('unaware', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('lovely', 'JJ'), ('melodies', 'NNS')]), ('filling', 'VBG'), Tree('NP', [('the', 'DT'), ('air', 'NN')]),  ...
#
# [Tree('S', [Tree('NP', [('The', 'DT'), ('story', 'NN')]), ('of', 'IN'), Tree('NP', [('Coda', 'NNP')]), ('is', 'VBZ'), Tree('NP', [('a', 'DT'), ('bit', 'NN')]), Tree('NP', [('cliché', 'NN')]), ('.', '.')]), Tree('S', [('Just', 'RB'), ('by', 'IN'), ('reading', 'VBG'), Tree('NP', [('the', 'DT'), ('ingredients', 'NNS')]), ('you', 'PRP'), ('can', 'MD'), ('already', 'RB'), ('see', 'VB'), ('where', 'WRB'), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), ('is', 'VBZ'), ('going', 'VBG'), ('.', '.')]), Tree('S', [('So', 'RB'), Tree('NP', [('no', 'DT'), ('real', 'JJ'), ('surprises', 'NNS')]), ('in', 'IN'), Tree('NP', [('Coda', 'NNP')]), (',', ','), ('you', 'PRP'), ('will', 'MD'), ('exactly', 'RB'), ('know', 'VB'), Tree('NP', [('the', 'DT'), ('outcome', 'JJ'), ('way', 'NN')]), ('long', 'RB'), ('before', 'IN'), ('the', 'DT'), ('ending', 'VBG'), ('.', '.')]), Tree('S', [('That', 'DT'), ('said', 'VBD'), ('it', 'PRP'), ("'s", 'VBZ'), ('still', 'RB'), Tree('NP', [('an', 'DT'), ('enjoyable', 'JJ'), ('movie', 'NN')]), ('to', 'TO'), ('watch', 'VB'), ('.', '.')]), Tree('S', [Tree('NP', [('A', 'DT'), ('little', 'JJ'), ('bit', 'NN')]), ('emotional', 'JJ'), ('sometimes', 'RB'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('almost', 'RB'), ('normal', 'JJ'), ('as', 'IN'), ('you', 'PRP'), ('feel', 'VBP'), Tree('NP', [('compassion', 'NN')]), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('deaf', 'NN')]), Tree('NP', [('people', 'NNS')]), ('and', 'CC'), ('certainly', 'RB'), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('daughter', 'NN')]), ('that', 'WDT'), ('has', 'VBZ'), Tree('NP', [('a', 'DT'), ('lot', 'NN')]), ('on', 'IN'), ('her', 'PRP$'), Tree('NP', [('plate', 'NN')]), ('.', '.')]), Tree('S', [('Maybe', 'RB'), Tree('NP', [('a', 'DT'), ('bit', 'NN')]), ('too', 'RB'), Tree('NP', [('much', 'JJ'), ('singing', 'NN')]), ('in', 'IN'), ('my', 'PRP$'), Tree('NP', [('opinion', 'NN')]), ('but', 'CC'), ('that', 'DT'), ("'s", 'VBZ'), ('just', 'RB'), ('because', 'IN'), ('I', 'PRP'), ("'m", 'VBP'), ('not', 'RB'), Tree('NP', [('a', 'DT'), ('big', 'JJ'), ('fan', 'NN')]), ('of', 'IN'), ('singing', 'VBG'), ('in', 'IN'), Tree('NP', [('movies', 'NNS')]), ('unless', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), Tree('NP', [('the', 'DT'), ('music', 'NN')]), ('that', 'IN'), ('I', 'PRP'), ('like', 'VBP'), ('but', 'CC'), ('that', 'DT'), ("'s", 'VBZ'), ('not', 'RB'), ('likely', 'JJ'), ('to', 'TO'), ('happen', 'VB'), ('given', 'VBN'), ('my', 'PRP$'), Tree('NP', [('taste', 'NN')]), ('of', 'IN'), Tree('NP', [('music', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Coda', 'NNP')]), ('is', 'VBZ'), ('predictable', 'JJ'), ('but', 'CC'), ('it', 'PRP'), ('does', 'VBZ'), ("n't", 'RB'), ('really', 'RB'), ('matter', 'VB'), ('as', 'IN'), Tree('NP', [('the', 'DT'), ('acting', 'NN')]), ('is', 'VBZ'), ('really', 'RB'), ('good', 'JJ'), ('and', 'CC'), ('that', 'IN'), ('from', 'IN'), Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('cast', 'NN')]), ('.', '.')]), Tree('S', [('Certainly', 'RB'), ('worth', 'VBZ'), Tree('NP', [('a', 'DT'), ('watch', 'NN')]), ('.', '.')])]
